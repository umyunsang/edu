# %% [markdown]
# <a href="https://colab.research.google.com/github/umyunsang/edu/blob/main/ComputerScience/03_ai-ml-data/quantum-ml/work/10_spsa_optimizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day21 SPSA optimizer 실습
#
# - Source: Google Drive `Day21/3-3.py`
# - Runtime: Google Colab recommended. Do not install or execute dependencies locally for sync validation.

# %%
"""
============================================================
Lab 6-2. COBYLA Optimizer 적용
============================================================
"""


# ============================================================
# STEP 1. Library Import
# ============================================================

import numpy as np
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit
from qiskit import transpile

from qiskit.circuit import Parameter

from qiskit_aer import AerSimulator

# ============================================================
# STEP 2. Parameterized Quantum Circuit 생성
# ============================================================

print("=" * 80)
print("STEP 2. Parameterized Quantum Circuit")
print("=" * 80)

# 학습 대상 Parameter
theta = Parameter("θ")

# 1-Qubit Circuit
qc = QuantumCircuit(1)

# Parameterized Gate
qc.ry(theta, 0)

# Measurement
qc.measure_all()

print(qc.draw())

# ============================================================
# STEP 3. Quantum Simulator 준비
# ============================================================

print("\n")
print("=" * 80)
print("STEP 3. Aer Simulator")
print("=" * 80)

simulator = AerSimulator()

shots = 2048

print("Backend :", simulator)
print("Shots   :", shots)

# ============================================================
# STEP 4. Prediction Function 구현
# ============================================================

print("\n")
print("=" * 80)
print("STEP 4. Prediction Function")
print("=" * 80)


def predict(theta_value):
    """
    Parameter를 입력받아
    Quantum Circuit을 실행하고
    Prediction(Expectation Value)을 반환
    """

    # --------------------------------------
    # Parameter Binding
    # --------------------------------------

    bound = qc.assign_parameters(
        {theta: theta_value}
    )

    # --------------------------------------
    # Compile
    # --------------------------------------

    compiled = transpile(
        bound,
        simulator
    )

    # --------------------------------------
    # Run
    # --------------------------------------

    job = simulator.run(
        compiled,
        shots=shots
    )

    result = job.result()

    counts = result.get_counts()

    # --------------------------------------
    # Probability
    # --------------------------------------

    p0 = counts.get("0", 0) / shots
    p1 = counts.get("1", 0) / shots

    # --------------------------------------
    # Prediction
    #
    # <Z> = p0 - p1
    # --------------------------------------

    prediction = p0 - p1

    return prediction


# ============================================================
# STEP 5. Prediction Test
# ============================================================

print("\n")
print("=" * 80)
print("STEP 5. Prediction Test")
print("=" * 80)

test_angles = [
    0,
    np.pi / 2,
    np.pi
]

for angle in test_angles:

    pred = predict(angle)

    print(f"Theta : {angle:.3f}")
    print(f"Prediction : {pred:.4f}")
    print("-" * 40)

# ============================================================
# STEP 6. Target 설정
# ============================================================

print("\n")
print("=" * 80)
print("STEP 6. Target")
print("=" * 80)

target = -0.8

print("Target :", target)

# ============================================================
# STEP 7. Objective Function 구현
# ============================================================

print("\n")
print("=" * 80)
print("STEP 7. Objective Function")
print("=" * 80)


def objective(theta_value):
    """
    Optimizer가 호출할
    공통 Objective Function

    Input
    -----
    theta

    Output
    ------
    Loss
    """

    prediction = predict(theta_value)

    loss = (prediction - target) ** 2

    return loss


print("Objective Function 생성 완료")

# ============================================================
# STEP 8. Objective Function Test
# ============================================================

print("\n")
print("=" * 80)
print("STEP 8. Objective Function Test")
print("=" * 80)

test_parameters = [
    0.1,
    1.0,
    2.5
]

for theta_value in test_parameters:

    prediction = predict(theta_value)

    loss = objective(theta_value)

    print(f"Theta      : {theta_value:.3f}")
    print(f"Prediction : {prediction:.4f}")
    print(f"Loss       : {loss:.6f}")
    print("-" * 50)

# ============================================================
# STEP 9. Parameter Sweep
# ============================================================

print("\n")
print("=" * 80)
print("STEP 9. Parameter Sweep")
print("=" * 80)

angles = np.linspace(
    0,
    2 * np.pi,
    30
)

predictions = []

losses = []

for angle in angles:

    prediction = predict(angle)

    loss = objective(angle)

    predictions.append(prediction)

    losses.append(loss)

# 결과 출력

print("Parameter Sweep 완료")

print("Total Samples :", len(angles))

# ============================================================
# STEP 10. Prediction Graph
# ============================================================

plt.figure(figsize=(8,5))

plt.plot(
    angles,
    predictions,
    marker="o"
)

plt.axhline(
    y=target,
    color="red",
    linestyle="--",
    label="Target"
)

plt.title("Prediction")

plt.xlabel("Theta")

plt.ylabel("Prediction")

plt.grid(True)

plt.legend()

plt.show()

# ============================================================
# STEP 11. Loss Graph
# ============================================================

plt.figure(figsize=(8,5))

plt.plot(
    angles,
    losses,
    marker="o"
)

plt.title("Objective Function (Loss)")

plt.xlabel("Theta")

plt.ylabel("Loss")

plt.grid(True)

plt.show()

# ============================================================
# STEP 12. Best Parameter 찾기
# ============================================================

print("\n")
print("=" * 80)
print("STEP 12. Best Parameter")
print("=" * 80)

best_index = np.argmin(losses)

best_theta = angles[best_index]

best_prediction = predictions[best_index]

best_loss = losses[best_index]

print(f"Best Theta      : {best_theta:.4f}")

print(f"Prediction      : {best_prediction:.4f}")

print(f"Target          : {target:.4f}")

print(f"Loss            : {best_loss:.8f}")


print("=" * 80)
print("Lab Complete")
print("=" * 80)





# ============================================================
# STEP 1. Library Import
# ============================================================

import time
import numpy as np
import matplotlib.pyplot as plt

from qiskit_algorithms.optimizers import COBYLA

# ============================================================
# STEP 2. Part 6 코드 준비
# ============================================================

"""
Part 6에서 다음 객체들이 이미 생성되어 있다고 가정한다.

theta
qc
predict()
target
shots
simulator
"""

print("="*80)
print("STEP 2. Common Objective Function")
print("="*80)

print("Part 6의 Objective Function 재사용")




"""
============================================================
Lab 6-3. SPSA Optimizer 적용
============================================================
"""


# ============================================================
# STEP 1. Library Import
# ============================================================

import time
import numpy as np
import matplotlib.pyplot as plt

from qiskit_algorithms.optimizers import SPSA

# ============================================================
# STEP 2. Part 6 코드 준비
# ============================================================

print("="*80)
print("STEP 2. Common Objective Function")
print("="*80)

print("Part 6 Objective Function 재사용")

# ============================================================
# STEP 3. SPSA History
# ============================================================

print("\n")
print("="*80)
print("STEP 3. SPSA History")
print("="*80)

spsa_history = {

    "evaluation": [],

    "parameter": [],

    "prediction": [],

    "loss": [],

    "best_loss": []

}

# ============================================================
# STEP 4. SPSA Objective Function
# ============================================================

print("\n")
print("="*80)
print("STEP 4. SPSA Objective")
print("="*80)

def spsa_objective(parameters):

    theta_value = float(parameters[0])

    prediction = predict(theta_value)

    loss = (prediction-target)**2

    evaluation = len(
        spsa_history["evaluation"]
    ) + 1

    spsa_history["evaluation"].append(
        evaluation
    )

    spsa_history["parameter"].append(
        theta_value
    )

    spsa_history["prediction"].append(
        prediction
    )

    spsa_history["loss"].append(
        loss
    )

    current_best = min(
        spsa_history["loss"]
    )

    spsa_history["best_loss"].append(
        current_best
    )

    print(
        f"[{evaluation:03d}] "
        f"Theta={theta_value:8.4f} "
        f"Prediction={prediction:8.4f} "
        f"Loss={loss:10.6f}"
    )

    return float(loss)

# ============================================================
# STEP 5. Initial Parameter
# ============================================================

print("\n")
print("="*80)
print("STEP 5. Initial Parameter")
print("="*80)

initial_point = np.array([0.2])

initial_prediction = predict(
    initial_point[0]
)

initial_loss = (
    initial_prediction-target
)**2

print("Initial Parameter :", initial_point[0])

print("Initial Prediction :", initial_prediction)

print("Initial Loss :", initial_loss)

# ============================================================
# STEP 6. SPSA 생성
# ============================================================

print("\n")
print("="*80)
print("STEP 6. SPSA")
print("="*80)

optimizer = SPSA(

    maxiter=100

)

print(optimizer)

# ============================================================
# STEP 7. Optimization
# ============================================================

print("\n")
print("="*80)
print("STEP 7. Optimization")
print("="*80)

start = time.perf_counter()

result = optimizer.minimize(

    fun=spsa_objective,

    x0=initial_point

)

elapsed = time.perf_counter()-start

# ============================================================
# STEP 8. Result
# ============================================================

print("\n")
print("="*80)
print("STEP 8. Result")
print("="*80)

optimal_theta = float(result.x[0])

optimizer_loss = float(result.fun)

nfev = getattr(result,"nfev",None)

nit = getattr(result,"nit",None)

print("Optimal Theta :", optimal_theta)

print("Optimizer Loss :", optimizer_loss)

print("Function Evaluation :", nfev)

print("Iteration :", nit)

print("Elapsed Time :", elapsed)

# ============================================================
# STEP 9. Prediction Verification
# ============================================================

print("\n")
print("="*80)
print("STEP 9. Prediction Verification")
print("="*80)

final_prediction = predict(
    optimal_theta
)

verified_loss = (
    final_prediction-target
)**2

print("Prediction :", final_prediction)

print("Target :", target)

print("Verified Loss :", verified_loss)

# ============================================================
# STEP 10. Loss Curve
# ============================================================

plt.figure(figsize=(8,5))

plt.plot(

    spsa_history["evaluation"],

    spsa_history["loss"],

    marker="o",

    label="Loss"

)

plt.plot(

    spsa_history["evaluation"],

    spsa_history["best_loss"],

    linewidth=2,

    label="Best Loss"

)

plt.xlabel("Evaluation")

plt.ylabel("Loss")

plt.title("SPSA Loss Curve")

plt.grid(True)

plt.legend()

plt.show()

# ============================================================
# STEP 11. Parameter Curve
# ============================================================

plt.figure(figsize=(8,5))

plt.plot(

    spsa_history["evaluation"],

    spsa_history["parameter"],

    marker="o"

)

plt.xlabel("Evaluation")

plt.ylabel("Theta")

plt.title("SPSA Parameter Update")

plt.grid(True)

plt.show()

# ============================================================
# STEP 12. Prediction Curve
# ============================================================

plt.figure(figsize=(8,5))

plt.plot(

    spsa_history["evaluation"],

    spsa_history["prediction"],

    marker="o"

)

plt.axhline(

    y=target,

    color="red",

    linestyle="--",

    label="Target"

)

plt.xlabel("Evaluation")

plt.ylabel("Prediction")

plt.title("Prediction Convergence")

plt.grid(True)

plt.legend()

plt.show()

# ============================================================
# STEP 13. Loss Landscape
# ============================================================

theta_space = np.linspace(
    0,
    2*np.pi,
    300
)

landscape = (
    np.cos(theta_space)-target
)**2

plt.figure(figsize=(9,6))

plt.plot(

    theta_space,

    landscape,

    label="Loss Landscape"

)

plt.scatter(

    spsa_history["parameter"],

    spsa_history["loss"],

    color="red",

    label="SPSA"

)

plt.scatter(

    [initial_point[0]],

    [initial_loss],

    marker="s",

    s=100,

    label="Initial"

)

plt.scatter(

    [optimal_theta],

    [optimizer_loss],

    marker="*",

    s=200,

    label="Optimal"

)

plt.xlabel("Theta")

plt.ylabel("Loss")

plt.title("SPSA Search Path")

plt.grid(True)

plt.legend()

plt.show()

# ============================================================
# STEP 14. Summary
# ============================================================

print("\n")
print("="*80)
print("SUMMARY")
print("="*80)

print("Initial Parameter :", initial_point[0])

print("Optimal Parameter :", optimal_theta)

print("Initial Loss :", initial_loss)

print("Final Loss :", verified_loss)

print("Prediction :", final_prediction)

print("Function Evaluation :", nfev)

print("Iteration :", nit)

print()

print("="*80)
print("Lab Complete")
print("="*80)
# Out:
# ================================================================================
# STEP 2. Parameterized Quantum Circuit
# ================================================================================
#         ┌───────┐ ░ ┌─┐
#      q: ┤ Ry(θ) ├─░─┤M├
#         └───────┘ ░ └╥┘
# meas: 1/═════════════╩═
#                      0
#
#
# ================================================================================
# STEP 3. Aer Simulator
# ================================================================================
# Backend : AerSimulator('aer_simulator')
# Shots   : 2048
#
#
# ================================================================================
# STEP 4. Prediction Function
# ================================================================================
#
#
# ================================================================================
# STEP 5. Prediction Test
# ================================================================================
# Theta : 0.000
# Prediction : 1.0000
# ----------------------------------------
# Theta : 1.571
# Prediction : 0.0244
# ----------------------------------------
# Theta : 3.142
# Prediction : -1.0000
# ----------------------------------------
#
#
# ================================================================================
# STEP 6. Target
# ================================================================================
# Target : -0.8
#
#
# ================================================================================
# STEP 7. Objective Function
# ================================================================================
# Objective Function 생성 완료
#
#
# ================================================================================
# STEP 8. Objective Function Test
# ================================================================================
# Theta      : 0.100
# Prediction : 0.9932
# Loss       : 3.229462
# --------------------------------------------------
# Theta      : 1.000
# Prediction : 0.5273
# Loss       : 1.827249
# --------------------------------------------------
# Theta      : 2.500
# Prediction : -0.7969
# Loss       : 0.000032
# --------------------------------------------------
#
#
# ================================================================================
# STEP 9. Parameter Sweep
# ================================================================================
# Parameter Sweep 완료
# Total Samples : 30
# ================================================================================
# STEP 12. Best Parameter
# ================================================================================
# Best Theta      : 3.6832
# Prediction      : -0.8564
# Target          : -0.8000
# Loss            : 0.00143570
# ================================================================================
# Lab Complete
# ================================================================================
# ================================================================================
# STEP 2. Common Objective Function
# ================================================================================
# Part 6의 Objective Function 재사용
# ================================================================================
# STEP 2. Common Objective Function
# ================================================================================
# Part 6 Objective Function 재사용
#
#
# ================================================================================
# STEP 3. SPSA History
# ================================================================================
#
#
# ================================================================================
# STEP 4. SPSA Objective
# ================================================================================
#
#
# ================================================================================
# STEP 5. Initial Parameter
# ================================================================================
# Initial Parameter : 0.2
# Initial Prediction : 0.982421875
# Initial Loss : 3.1770277404785157
#
#
# ================================================================================
# STEP 6. SPSA
# ================================================================================
# <qiskit_algorithms.optimizers.spsa.SPSA object at 0x115070c20>
#
#
# ================================================================================
# STEP 7. Optimization
# ================================================================================
# [001] Theta=  0.4000 Prediction=  0.9248 Loss=  2.974951
# [002] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [003] Theta=  0.4000 Prediction=  0.9141 Loss=  2.938010
# [004] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [005] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [006] Theta=  0.4000 Prediction=  0.9199 Loss=  2.958131
# [007] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [008] Theta=  0.4000 Prediction=  0.9229 Loss=  2.968218
# [009] Theta=  0.4000 Prediction=  0.9141 Loss=  2.938010
# [010] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [011] Theta=  0.4000 Prediction=  0.9258 Loss=  2.978321
# [012] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [013] Theta=  0.4000 Prediction=  0.9307 Loss=  2.995198
# [014] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [015] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [016] Theta=  0.4000 Prediction=  0.9082 Loss=  2.917958
# [017] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [018] Theta=  0.4000 Prediction=  0.9170 Loss=  2.948062
# [019] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [020] Theta=  0.4000 Prediction=  0.9092 Loss=  2.921295
# [021] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [022] Theta=  0.4000 Prediction=  0.9082 Loss=  2.917958
# [023] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [024] Theta=  0.4000 Prediction=  0.9053 Loss=  2.907957
# [025] Theta=  0.4000 Prediction=  0.9229 Loss=  2.968218
# [026] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [027] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [028] Theta=  0.4000 Prediction=  0.9268 Loss=  2.981693
# [029] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [030] Theta=  0.4000 Prediction=  0.9160 Loss=  2.944710
# [031] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [032] Theta=  0.4000 Prediction=  0.9160 Loss=  2.944710
# [033] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [034] Theta=  0.4000 Prediction=  0.9092 Loss=  2.921295
# [035] Theta=  0.4000 Prediction=  0.9219 Loss=  2.964854
# [036] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [037] Theta=  0.4000 Prediction=  0.9082 Loss=  2.917958
# [038] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [039] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [040] Theta=  0.4000 Prediction=  0.9111 Loss=  2.927976
# [041] Theta=  0.4000 Prediction=  0.9248 Loss=  2.974951
# [042] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [043] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [044] Theta=  0.4000 Prediction=  0.9219 Loss=  2.964854
# [045] Theta=  0.4000 Prediction=  0.9365 Loss=  3.015514
# [046] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [047] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [048] Theta=  0.4000 Prediction=  0.9131 Loss=  2.934663
# [049] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [050] Theta=  0.4000 Prediction=  0.9160 Loss=  2.944710
# [051] Theta=  0.4000 Prediction=  0.9180 Loss=  2.951417
# [052] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [053] Theta=  0.6405 Prediction=  0.8105 Loss=  2.593861
# [054] Theta=  1.0135 Prediction=  0.5488 Loss=  1.819337
# [055] Theta=  1.8371 Prediction= -0.2402 Loss=  0.313338
# [056] Theta=  2.1951 Prediction= -0.5752 Loss=  0.050537
# [057] Theta=  2.5192 Prediction= -0.8428 Loss=  0.001830
# [058] Theta=  2.1715 Prediction= -0.5635 Loss=  0.055943
# [059] Theta=  2.5741 Prediction= -0.8398 Loss=  0.001588
# [060] Theta=  2.2341 Prediction= -0.6006 Loss=  0.039766
# [061] Theta=  2.2742 Prediction= -0.6680 Loss=  0.017432
# [062] Theta=  2.6080 Prediction= -0.8691 Loss=  0.004780
# [063] Theta=  2.6166 Prediction= -0.8574 Loss=  0.003297
# [064] Theta=  2.2880 Prediction= -0.6787 Loss=  0.014711
# [065] Theta=  2.6238 Prediction= -0.8662 Loss=  0.004384
# [066] Theta=  2.2995 Prediction= -0.6562 Loss=  0.020664
# [067] Theta=  2.3139 Prediction= -0.6426 Loss=  0.024782
# [068] Theta=  2.6343 Prediction= -0.8857 Loss=  0.007352
# [069] Theta=  2.6452 Prediction= -0.8691 Loss=  0.004780
# [070] Theta=  2.3282 Prediction= -0.6924 Loss=  0.011581
# [071] Theta=  2.6484 Prediction= -0.8906 Loss=  0.008213
# [072] Theta=  2.3344 Prediction= -0.6855 Loss=  0.013100
# [073] Theta=  2.6502 Prediction= -0.8740 Loss=  0.005479
# [074] Theta=  2.3390 Prediction= -0.6992 Loss=  0.010157
# [075] Theta=  2.6519 Prediction= -0.8857 Loss=  0.007352
# [076] Theta=  2.3432 Prediction= -0.6992 Loss=  0.010157
# [077] Theta=  2.6524 Prediction= -0.8789 Loss=  0.006226
# [078] Theta=  2.3460 Prediction= -0.6729 Loss=  0.016167
# [079] Theta=  2.3528 Prediction= -0.7217 Loss=  0.006134
# [080] Theta=  2.6571 Prediction= -0.8770 Loss=  0.005922
# [081] Theta=  2.6562 Prediction= -0.8799 Loss=  0.006381
# [082] Theta=  2.3539 Prediction= -0.7178 Loss=  0.006761
# [083] Theta=  2.3551 Prediction= -0.6621 Loss=  0.019014
# [084] Theta=  2.6555 Prediction= -0.8936 Loss=  0.008752
# [085] Theta=  2.3613 Prediction= -0.7148 Loss=  0.007252
# [086] Theta=  2.6600 Prediction= -0.8701 Loss=  0.004916
# [087] Theta=  2.6604 Prediction= -0.8955 Loss=  0.009122
# [088] Theta=  2.3633 Prediction= -0.7148 Loss=  0.007252
# [089] Theta=  2.6587 Prediction= -0.8691 Loss=  0.004780
# [090] Theta=  2.3632 Prediction= -0.7227 Loss=  0.005982
# [091] Theta=  2.6586 Prediction= -0.8984 Loss=  0.009690
# [092] Theta=  2.3645 Prediction= -0.7148 Loss=  0.007252
# [093] Theta=  2.6567 Prediction= -0.8828 Loss=  0.006858
# [094] Theta=  2.3640 Prediction= -0.7139 Loss=  0.007419
# [095] Theta=  2.6563 Prediction= -0.8750 Loss=  0.005625
# [096] Theta=  2.3649 Prediction= -0.7061 Loss=  0.008826
# [097] Theta=  2.3670 Prediction= -0.6875 Loss=  0.012656
# [098] Theta=  2.6572 Prediction= -0.8916 Loss=  0.008391
# [099] Theta=  2.6585 Prediction= -0.8652 Loss=  0.004256
# [100] Theta=  2.3695 Prediction= -0.7139 Loss=  0.007419
# [101] Theta=  2.6592 Prediction= -0.9043 Loss=  0.010878
# [102] Theta=  2.3714 Prediction= -0.7227 Loss=  0.005982
# [103] Theta=  2.3699 Prediction= -0.7168 Loss=  0.006923
# [104] Theta=  2.6566 Prediction= -0.8721 Loss=  0.005194
# [105] Theta=  2.3711 Prediction= -0.7217 Loss=  0.006134
# [106] Theta=  2.6568 Prediction= -0.8848 Loss=  0.007185
# [107] Theta=  2.6559 Prediction= -0.8750 Loss=  0.005625
# [108] Theta=  2.3712 Prediction= -0.7197 Loss=  0.006444
# [109] Theta=  2.3720 Prediction= -0.7354 Loss=  0.004179
# [110] Theta=  2.6557 Prediction= -0.8867 Loss=  0.007520
# [111] Theta=  2.6539 Prediction= -0.9004 Loss=  0.010078
# [112] Theta=  2.3712 Prediction= -0.7051 Loss=  0.009010
# [113] Theta=  2.6531 Prediction= -0.8965 Loss=  0.009309
# [114] Theta=  2.3712 Prediction= -0.7129 Loss=  0.007588
# [115] Theta=  2.3710 Prediction= -0.6973 Loss=  0.010554
# [116] Theta=  2.6520 Prediction= -0.8926 Loss=  0.008571
# [117] Theta=  2.6523 Prediction= -0.8926 Loss=  0.008571
# [118] Theta=  2.3722 Prediction= -0.7217 Loss=  0.006134
# [119] Theta=  2.6510 Prediction= -0.8877 Loss=  0.007690
# [120] Theta=  2.3717 Prediction= -0.7412 Loss=  0.003456
# [121] Theta=  2.6490 Prediction= -0.8955 Loss=  0.009122
# [122] Theta=  2.3705 Prediction= -0.7217 Loss=  0.006134
# [123] Theta=  2.3698 Prediction= -0.7344 Loss=  0.004307
# [124] Theta=  2.6476 Prediction= -0.8623 Loss=  0.003882
# [125] Theta=  2.3703 Prediction= -0.6865 Loss=  0.012877
# [126] Theta=  2.6473 Prediction= -0.8877 Loss=  0.007690
# [127] Theta=  2.3725 Prediction= -0.7451 Loss=  0.003012
# [128] Theta=  2.6488 Prediction= -0.8857 Loss=  0.007352
# [129] Theta=  2.3714 Prediction= -0.7324 Loss=  0.004567
# [130] Theta=  2.6470 Prediction= -0.8896 Loss=  0.008037
# [131] Theta=  2.3705 Prediction= -0.7129 Loss=  0.007588
# [132] Theta=  2.6454 Prediction= -0.8828 Loss=  0.006858
# [133] Theta=  2.6453 Prediction= -0.8750 Loss=  0.005625
# [134] Theta=  2.3711 Prediction= -0.7070 Loss=  0.008643
# [135] Theta=  2.6460 Prediction= -0.8838 Loss=  0.007021
# [136] Theta=  2.3724 Prediction= -0.7295 Loss=  0.004971
# [137] Theta=  2.6450 Prediction= -0.8828 Loss=  0.006858
# [138] Theta=  2.3721 Prediction= -0.7275 Loss=  0.005251
# [139] Theta=  2.3719 Prediction= -0.7314 Loss=  0.004700
# [140] Theta=  2.6442 Prediction= -0.8857 Loss=  0.007352
# [141] Theta=  2.3713 Prediction= -0.7041 Loss=  0.009197
# [142] Theta=  2.6430 Prediction= -0.8770 Loss=  0.005922
# [143] Theta=  2.3726 Prediction= -0.7178 Loss=  0.006761
# [144] Theta=  2.6438 Prediction= -0.9121 Loss=  0.012569
# [145] Theta=  2.3711 Prediction= -0.6895 Loss=  0.012221
# [146] Theta=  2.6417 Prediction= -0.8672 Loss=  0.004514
# [147] Theta=  2.3738 Prediction= -0.7256 Loss=  0.005537
# [148] Theta=  2.6438 Prediction= -0.8838 Loss=  0.007021
# [149] Theta=  2.6431 Prediction= -0.8486 Loss=  0.002365
# [150] Theta=  2.3736 Prediction= -0.7090 Loss=  0.008284
# [151] Theta=  2.3757 Prediction= -0.7285 Loss=  0.005110
# [152] Theta=  2.6446 Prediction= -0.8770 Loss=  0.005922
# [153] Theta=  2.6441 Prediction= -0.9023 Loss=  0.010474
# [154] Theta=  2.3757 Prediction= -0.7441 Loss=  0.003120
# [155] Theta=  2.3738 Prediction= -0.7148 Loss=  0.007252
# [156] Theta=  2.6416 Prediction= -0.8779 Loss=  0.006073
# [157] Theta=  2.6417 Prediction= -0.8662 Loss=  0.004384
# [158] Theta=  2.3744 Prediction= -0.7168 Loss=  0.006923
# [159] Theta=  2.6422 Prediction= -0.8682 Loss=  0.004646
# [160] Theta=  2.3754 Prediction= -0.7471 Loss=  0.002802
# [161] Theta=  2.6414 Prediction= -0.8672 Loss=  0.004514
# [162] Theta=  2.3751 Prediction= -0.7158 Loss=  0.007086
# [163] Theta=  2.6419 Prediction= -0.8916 Loss=  0.008391
# [164] Theta=  2.3760 Prediction= -0.6982 Loss=  0.010355
# [165] Theta=  2.3768 Prediction= -0.7139 Loss=  0.007419
# [166] Theta=  2.6423 Prediction= -0.8809 Loss=  0.006538
# [167] Theta=  2.6423 Prediction= -0.8672 Loss=  0.004514
# [168] Theta=  2.3773 Prediction= -0.7266 Loss=  0.005393
# [169] Theta=  2.6423 Prediction= -0.8838 Loss=  0.007021
# [170] Theta=  2.3778 Prediction= -0.7227 Loss=  0.005982
# [171] Theta=  2.3777 Prediction= -0.7041 Loss=  0.009197
# [172] Theta=  2.6418 Prediction= -0.8818 Loss=  0.006697
# [173] Theta=  2.6423 Prediction= -0.8682 Loss=  0.004646
# [174] Theta=  2.3786 Prediction= -0.7305 Loss=  0.004835
# [175] Theta=  2.6421 Prediction= -0.8779 Loss=  0.006073
# [176] Theta=  2.3789 Prediction= -0.7441 Loss=  0.003120
# [177] Theta=  2.3783 Prediction= -0.7422 Loss=  0.003342
# [178] Theta=  2.6411 Prediction= -0.8555 Loss=  0.003077
# [179] Theta=  2.6410 Prediction= -0.8838 Loss=  0.007021
# [180] Theta=  2.3786 Prediction= -0.7363 Loss=  0.004054
# [181] Theta=  2.6400 Prediction= -0.8604 Loss=  0.003642
# [182] Theta=  2.3780 Prediction= -0.7236 Loss=  0.005832
# [183] Theta=  2.3788 Prediction= -0.7305 Loss=  0.004835
# [184] Theta=  2.6404 Prediction= -0.8867 Loss=  0.007520
# [185] Theta=  2.6395 Prediction= -0.8730 Loss=  0.005336
# [186] Theta=  2.3783 Prediction= -0.7314 Loss=  0.004700
# [187] Theta=  2.3783 Prediction= -0.7266 Loss=  0.005393
# [188] Theta=  2.6391 Prediction= -0.8701 Loss=  0.004916
# [189] Theta=  2.3786 Prediction= -0.7227 Loss=  0.005982
# [190] Theta=  2.6390 Prediction= -0.8936 Loss=  0.008752
# [191] Theta=  2.6381 Prediction= -0.8896 Loss=  0.008037
# [192] Theta=  2.3781 Prediction= -0.7051 Loss=  0.009010
# [193] Theta=  2.3785 Prediction= -0.6846 Loss=  0.013324
# [194] Theta=  2.6382 Prediction= -0.8662 Loss=  0.004384
# [195] Theta=  2.3810 Prediction= -0.7344 Loss=  0.004307
# [196] Theta=  2.6403 Prediction= -0.8701 Loss=  0.004916
# [197] Theta=  2.3810 Prediction= -0.7148 Loss=  0.007252
# [198] Theta=  2.6400 Prediction= -0.8770 Loss=  0.005922
# [199] Theta=  2.3815 Prediction= -0.7461 Loss=  0.002906
# [200] Theta=  2.6401 Prediction= -0.8721 Loss=  0.005194
# [201] Theta=  2.6394 Prediction= -0.8682 Loss=  0.004646
# [202] Theta=  2.3811 Prediction= -0.7119 Loss=  0.007759
# [203] Theta=  2.6400 Prediction= -0.8691 Loss=  0.004780
# [204] Theta=  2.3820 Prediction= -0.7275 Loss=  0.005251
# [205] Theta=  2.6399 Prediction= -0.8750 Loss=  0.005625
# [206] Theta=  2.3823 Prediction= -0.7432 Loss=  0.003230
# [207] Theta=  2.3819 Prediction= -0.6914 Loss=  0.011793
# [208] Theta=  2.6392 Prediction= -0.8799 Loss=  0.006381
# [209] Theta=  2.3834 Prediction= -0.7227 Loss=  0.005982
# [210] Theta=  2.6403 Prediction= -0.8691 Loss=  0.004780
# [211] Theta=  2.6405 Prediction= -0.8877 Loss=  0.007690
# [212] Theta=  2.3838 Prediction= -0.7412 Loss=  0.003456
# [213] Theta=  2.6393 Prediction= -0.8760 Loss=  0.005772
# [214] Theta=  2.3830 Prediction= -0.7285 Loss=  0.005110
# [215] Theta=  2.3830 Prediction= -0.7207 Loss=  0.006288
# [216] Theta=  2.6390 Prediction= -0.8838 Loss=  0.007021
# [217] Theta=  2.3829 Prediction= -0.7031 Loss=  0.009385
# [218] Theta=  2.6386 Prediction= -0.8906 Loss=  0.008213
# [219] Theta=  2.6388 Prediction= -0.8730 Loss=  0.005336
# [220] Theta=  2.3834 Prediction= -0.6953 Loss=  0.010959
# [221] Theta=  2.3848 Prediction= -0.7197 Loss=  0.006444
# [222] Theta=  2.6399 Prediction= -0.8701 Loss=  0.004916
# [223] Theta=  2.6401 Prediction= -0.8779 Loss=  0.006073
# [224] Theta=  2.3854 Prediction= -0.7188 Loss=  0.006602
# [225] Theta=  2.6401 Prediction= -0.8643 Loss=  0.004129
# [226] Theta=  2.3856 Prediction= -0.7188 Loss=  0.006602
# [227] Theta=  2.3863 Prediction= -0.7227 Loss=  0.005982
# [228] Theta=  2.6405 Prediction= -0.8770 Loss=  0.005922
# [229] Theta=  2.3865 Prediction= -0.7285 Loss=  0.005110
# [230] Theta=  2.6404 Prediction= -0.8730 Loss=  0.005336
# [231] Theta=  2.6402 Prediction= -0.8701 Loss=  0.004916
# [232] Theta=  2.3866 Prediction= -0.7344 Loss=  0.004307
# [233] Theta=  2.3866 Prediction= -0.7510 Loss=  0.002403
# [234] Theta=  2.6399 Prediction= -0.8701 Loss=  0.004916
# [235] Theta=  2.3862 Prediction= -0.7168 Loss=  0.006923
# [236] Theta=  2.6392 Prediction= -0.8701 Loss=  0.004916
# [237] Theta=  2.3867 Prediction= -0.7373 Loss=  0.003931
# [238] Theta=  2.6395 Prediction= -0.8574 Loss=  0.003297
# [239] Theta=  2.3870 Prediction= -0.7266 Loss=  0.005393
# [240] Theta=  2.6395 Prediction= -0.8701 Loss=  0.004916
# [241] Theta=  2.3873 Prediction= -0.7070 Loss=  0.008643
# [242] Theta=  2.6395 Prediction= -0.8906 Loss=  0.008213
# [243] Theta=  2.3875 Prediction= -0.7266 Loss=  0.005393
# [244] Theta=  2.6395 Prediction= -0.8760 Loss=  0.005772
# [245] Theta=  2.3875 Prediction= -0.7363 Loss=  0.004054
# [246] Theta=  2.6393 Prediction= -0.8779 Loss=  0.006073
# [247] Theta=  2.6387 Prediction= -0.8711 Loss=  0.005054
# [248] Theta=  2.3872 Prediction= -0.7275 Loss=  0.005251
# [249] Theta=  2.3874 Prediction= -0.7178 Loss=  0.006761
# [250] Theta=  2.6386 Prediction= -0.8633 Loss=  0.004005
# [251] Theta=  2.5136 Prediction= -0.8184 Loss=  0.000337
#
#
# ================================================================================
# STEP 8. Result
# ================================================================================
# Optimal Theta : 2.5135979066276106
# Optimizer Loss : 0.00033706665039062337
# Function Evaluation : 200
# Iteration : 100
# Elapsed Time : 25.998553292127326
#
#
# ================================================================================
# STEP 9. Prediction Verification
# ================================================================================
# Prediction : -0.7880859375
# Target : -0.8
# Verified Loss : 0.0001419448852539073
# ================================================================================
# SUMMARY
# ================================================================================
# Initial Parameter : 0.2
# Optimal Parameter : 2.5135979066276106
# Initial Loss : 3.1770277404785157
# Final Loss : 0.0001419448852539073
# Prediction : -0.7880859375
# Function Evaluation : 200
# Iteration : 100
#
# ================================================================================
# Lab Complete
# ================================================================================
