# %% [markdown]
# <a href="https://colab.research.google.com/github/umyunsang/edu/blob/main/ComputerScience/03_ai-ml-data/quantum-ml/05.quantum-neural-networks/01.classical-neural-network-baseline/day33_01_01_pytorch_basic_model_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day33 PyTorch 기본 모델 실행 실습
#
# - Source: Google Drive `Day33/1-1.py`
# - Runtime: Google Colab recommended. Do not install or execute dependencies locally for sync validation.

# %%
"""
============================================================
 Lab. PyTorch 기본 모델 실행
============================================================

실습 목표
------------------------------------------------------------
1. PyTorch Tensor 생성
2. nn.Sequential 모델 생성
3. 모델 구조 확인
4. Forward 수행
5. Output Shape 확인
6. Weight / Bias 확인
7. Trainable Parameter 확인

"""

# ============================================================
# STEP 1. PyTorch Import
# ============================================================

print("=" * 70)
print("STEP 1. PyTorch Import")
print("=" * 70)

import torch
import torch.nn as nn

# 항상 동일한 결과를 얻기 위해 Seed 고정
torch.manual_seed(42)

print("PyTorch Version :", torch.__version__)




# ============================================================
# STEP 2. Input Tensor 생성
# ============================================================

print("\n")
print("=" * 70)
print("STEP 2. Input Tensor 생성")
print("=" * 70)

# Feature가 2개인 Sample 1개
x = torch.tensor(
    [[0.2, 0.7]],
    dtype=torch.float32
)

print("Input Tensor")
print(x)

print("\nTensor Shape")
print(x.shape)

print("\nTensor dtype")
print(x.dtype)




# ============================================================
# STEP 3. Neural Network 생성
# ============================================================

print("\n")
print("=" * 70)
print("STEP 3. Neural Network 생성")
print("=" * 70)

model = nn.Sequential(

    nn.Linear(
        in_features=2,
        out_features=4
    ),

    nn.ReLU(),

    nn.Linear(
        in_features=4,
        out_features=1
    )

)

print("Neural Network 생성 완료")




# ============================================================
# STEP 4. Model 구조 확인
# ============================================================

print("\n")
print("=" * 70)
print("STEP 4. Model 구조 확인")
print("=" * 70)

print(model)




# ============================================================
# STEP 5. Forward 수행
# ============================================================

print("\n")
print("=" * 70)
print("STEP 5. Forward 수행")
print("=" * 70)

output = model(x)

print("Forward 완료")




# ============================================================
# STEP 6. Output 확인
# ============================================================

print("\n")
print("=" * 70)
print("STEP 6. Output 확인")
print("=" * 70)

print("Output Tensor")

print(output)




# ============================================================
# STEP 7. Output Shape 확인
# ============================================================

print("\n")
print("=" * 70)
print("STEP 7. Shape 변화 확인")
print("=" * 70)

print("Input Shape")
print(x.shape)

print()

print("Output Shape")
print(output.shape)

print()

print("Shape 변화")
print(f"{x.shape}  --->  {output.shape}")




# ============================================================
# STEP 8. Weight와 Bias 확인
# ============================================================

print("\n")
print("=" * 70)
print("STEP 8. Weight와 Bias 확인")
print("=" * 70)

first_layer = model[0]

print("First Linear Layer")

print(first_layer)

print("\nWeight")

print(first_layer.weight)

print("\nWeight Shape")

print(first_layer.weight.shape)

print("\nBias")

print(first_layer.bias)

print("\nBias Shape")

print(first_layer.bias.shape)




# ============================================================
# STEP 9. Trainable Parameter 확인
# ============================================================

print("\n")
print("=" * 70)
print("STEP 9. Trainable Parameter 확인")
print("=" * 70)

for name, param in model.named_parameters():

    print("-" * 60)

    print("Parameter Name")

    print(name)

    print()

    print("Shape")

    print(param.shape)

    print()

    print("Requires Grad")

    print(param.requires_grad)

    print()

    print("Value")

    print(param)





# ============================================================
# STEP 10. Parameter 개수 확인
# ============================================================

print("\n")
print("=" * 70)
print("STEP 10. Parameter 개수 확인")
print("=" * 70)

total_parameter = sum(

    p.numel()

    for p in model.parameters()

)

print("Total Trainable Parameters")

print(total_parameter)





# ============================================================
# STEP 11. 전체 실행 결과 요약
# ============================================================

print("\n")
print("=" * 70)
print("STEP 11. 실행 결과 요약")
print("=" * 70)

print(f"""
Input Tensor Shape  : {x.shape}

Output Tensor Shape : {output.shape}

Model

Input
   ↓
Linear(2 → 4)
   ↓
ReLU
   ↓
Linear(4 → 1)
   ↓
Output

Forward 수행 완료

Weight 확인 완료

Bias 확인 완료

Trainable Parameter 확인 완료
""")
# Out:
# ======================================================================
# STEP 1. PyTorch Import
# ======================================================================
# PyTorch Version : 2.13.0
#
#
# ======================================================================
# STEP 2. Input Tensor 생성
# ======================================================================
# Input Tensor
# tensor([[0.2000, 0.7000]])
#
# Tensor Shape
# torch.Size([1, 2])
#
# Tensor dtype
# torch.float32
#
#
# ======================================================================
# STEP 3. Neural Network 생성
# ======================================================================
# Neural Network 생성 완료
#
#
# ======================================================================
# STEP 4. Model 구조 확인
# ======================================================================
# Sequential(
#   (0): Linear(in_features=2, out_features=4, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=4, out_features=1, bias=True)
# )
#
#
# ======================================================================
# STEP 5. Forward 수행
# ======================================================================
# Forward 완료
#
#
# ======================================================================
# STEP 6. Output 확인
# ======================================================================
# Output Tensor
# tensor([[0.9472]], grad_fn=<AddmmBackward0>)
#
#
# ======================================================================
# STEP 7. Shape 변화 확인
# ======================================================================
# Input Shape
# torch.Size([1, 2])
#
# Output Shape
# torch.Size([1, 1])
#
# Shape 변화
# torch.Size([1, 2])  --->  torch.Size([1, 1])
#
#
# ======================================================================
# STEP 8. Weight와 Bias 확인
# ======================================================================
# First Linear Layer
# Linear(in_features=2, out_features=4, bias=True)
#
# Weight
# Parameter containing:
# tensor([[ 0.5406,  0.5869],
#         [-0.1657,  0.6496],
#         [-0.1549,  0.1427],
#         [-0.3443,  0.4153]], requires_grad=True)
#
# Weight Shape
# torch.Size([4, 2])
#
# Bias
# Parameter containing:
# tensor([ 0.6233, -0.5188,  0.6146,  0.1323], requires_grad=True)
#
# Bias Shape
# torch.Size([4])
#
#
# ======================================================================
# STEP 9. Trainable Parameter 확인
# ======================================================================
# ------------------------------------------------------------
# Parameter Name
# 0.weight
#
# Shape
# torch.Size([4, 2])
#
# Requires Grad
# True
#
# Value
# Parameter containing:
# tensor([[ 0.5406,  0.5869],
#         [-0.1657,  0.6496],
#         [-0.1549,  0.1427],
#         [-0.3443,  0.4153]], requires_grad=True)
# ------------------------------------------------------------
# Parameter Name
# 0.bias
#
# Shape
# torch.Size([4])
#
# Requires Grad
# True
#
# Value
# Parameter containing:
# tensor([ 0.6233, -0.5188,  0.6146,  0.1323], requires_grad=True)
# ------------------------------------------------------------
# Parameter Name
# 2.weight
#
# Shape
# torch.Size([1, 4])
#
# Requires Grad
# True
#
# Value
# Parameter containing:
# tensor([[ 0.3694,  0.0677,  0.2411, -0.0706]], requires_grad=True)
# ------------------------------------------------------------
# Parameter Name
# 2.bias
#
# Shape
# torch.Size([1])
#
# Requires Grad
# True
#
# Value
# Parameter containing:
# tensor([0.3854], requires_grad=True)
#
#
# ======================================================================
# STEP 10. Parameter 개수 확인
# ======================================================================
# Total Trainable Parameters
# 17
#
#
# ======================================================================
# STEP 11. 실행 결과 요약
# ======================================================================
#
# Input Tensor Shape  : torch.Size([1, 2])
#
# Output Tensor Shape : torch.Size([1, 1])
#
# Model
#
# Input
#    ↓
# Linear(2 → 4)
#    ↓
# ReLU
#    ↓
# Linear(4 → 1)
#    ↓
# Output
#
# Forward 수행 완료
#
# Weight 확인 완료
#
# Bias 확인 완료
#
# Trainable Parameter 확인 완료
