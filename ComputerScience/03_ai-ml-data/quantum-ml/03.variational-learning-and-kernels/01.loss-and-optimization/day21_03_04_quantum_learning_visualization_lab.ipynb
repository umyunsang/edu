# %% [markdown]
# <a href="https://colab.research.google.com/github/umyunsang/edu/blob/main/ComputerScience/03_ai-ml-data/quantum-ml/03.variational-learning-and-kernels/01.loss-and-optimization/day21_03_04_quantum_learning_visualization_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day21 quantum learning visualization 실습
#
# - Source: Google Drive `Day21/3-4.py`
# - Runtime: Google Colab recommended. Do not install or execute dependencies locally for sync validation.

# %%
"""
============================================================
Lab 6-2. COBYLA Optimizer 적용
============================================================
"""


# ============================================================
# STEP 1. Library Import
# ============================================================

import numpy as np
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit
from qiskit import transpile

from qiskit.circuit import Parameter

from qiskit_aer import AerSimulator

# ============================================================
# STEP 2. Parameterized Quantum Circuit 생성
# ============================================================

print("=" * 80)
print("STEP 2. Parameterized Quantum Circuit")
print("=" * 80)

# 학습 대상 Parameter
theta = Parameter("θ")

# 1-Qubit Circuit
qc = QuantumCircuit(1)

# Parameterized Gate
qc.ry(theta, 0)

# Measurement
qc.measure_all()

print(qc.draw())

# ============================================================
# STEP 3. Quantum Simulator 준비
# ============================================================

print("\n")
print("=" * 80)
print("STEP 3. Aer Simulator")
print("=" * 80)

simulator = AerSimulator()

shots = 2048

print("Backend :", simulator)
print("Shots   :", shots)

# ============================================================
# STEP 4. Prediction Function 구현
# ============================================================

print("\n")
print("=" * 80)
print("STEP 4. Prediction Function")
print("=" * 80)


def predict(theta_value):
    """
    Parameter를 입력받아
    Quantum Circuit을 실행하고
    Prediction(Expectation Value)을 반환
    """

    # --------------------------------------
    # Parameter Binding
    # --------------------------------------

    bound = qc.assign_parameters(
        {theta: theta_value}
    )

    # --------------------------------------
    # Compile
    # --------------------------------------

    compiled = transpile(
        bound,
        simulator
    )

    # --------------------------------------
    # Run
    # --------------------------------------

    job = simulator.run(
        compiled,
        shots=shots
    )

    result = job.result()

    counts = result.get_counts()

    # --------------------------------------
    # Probability
    # --------------------------------------

    p0 = counts.get("0", 0) / shots
    p1 = counts.get("1", 0) / shots

    # --------------------------------------
    # Prediction
    #
    # <Z> = p0 - p1
    # --------------------------------------

    prediction = p0 - p1

    return prediction


# ============================================================
# STEP 5. Prediction Test
# ============================================================

print("\n")
print("=" * 80)
print("STEP 5. Prediction Test")
print("=" * 80)

test_angles = [
    0,
    np.pi / 2,
    np.pi
]

for angle in test_angles:

    pred = predict(angle)

    print(f"Theta : {angle:.3f}")
    print(f"Prediction : {pred:.4f}")
    print("-" * 40)

# ============================================================
# STEP 6. Target 설정
# ============================================================

print("\n")
print("=" * 80)
print("STEP 6. Target")
print("=" * 80)

target = -0.8

print("Target :", target)

# ============================================================
# STEP 7. Objective Function 구현
# ============================================================

print("\n")
print("=" * 80)
print("STEP 7. Objective Function")
print("=" * 80)


def objective(theta_value):
    """
    Optimizer가 호출할
    공통 Objective Function

    Input
    -----
    theta

    Output
    ------
    Loss
    """

    prediction = predict(theta_value)

    loss = (prediction - target) ** 2

    return loss


print("Objective Function 생성 완료")

# ============================================================
# STEP 8. Objective Function Test
# ============================================================

print("\n")
print("=" * 80)
print("STEP 8. Objective Function Test")
print("=" * 80)

test_parameters = [
    0.1,
    1.0,
    2.5
]

for theta_value in test_parameters:

    prediction = predict(theta_value)

    loss = objective(theta_value)

    print(f"Theta      : {theta_value:.3f}")
    print(f"Prediction : {prediction:.4f}")
    print(f"Loss       : {loss:.6f}")
    print("-" * 50)

# ============================================================
# STEP 9. Parameter Sweep
# ============================================================

print("\n")
print("=" * 80)
print("STEP 9. Parameter Sweep")
print("=" * 80)

angles = np.linspace(
    0,
    2 * np.pi,
    30
)

predictions = []

losses = []

for angle in angles:

    prediction = predict(angle)

    loss = objective(angle)

    predictions.append(prediction)

    losses.append(loss)

# 결과 출력

print("Parameter Sweep 완료")

print("Total Samples :", len(angles))

# ============================================================
# STEP 10. Prediction Graph
# ============================================================

plt.figure(figsize=(8,5))

plt.plot(
    angles,
    predictions,
    marker="o"
)

plt.axhline(
    y=target,
    color="red",
    linestyle="--",
    label="Target"
)

plt.title("Prediction")

plt.xlabel("Theta")

plt.ylabel("Prediction")

plt.grid(True)

plt.legend()

plt.show()

# ============================================================
# STEP 11. Loss Graph
# ============================================================

plt.figure(figsize=(8,5))

plt.plot(
    angles,
    losses,
    marker="o"
)

plt.title("Objective Function (Loss)")

plt.xlabel("Theta")

plt.ylabel("Loss")

plt.grid(True)

plt.show()

# ============================================================
# STEP 12. Best Parameter 찾기
# ============================================================

print("\n")
print("=" * 80)
print("STEP 12. Best Parameter")
print("=" * 80)

best_index = np.argmin(losses)

best_theta = angles[best_index]

best_prediction = predictions[best_index]

best_loss = losses[best_index]

print(f"Best Theta      : {best_theta:.4f}")

print(f"Prediction      : {best_prediction:.4f}")

print(f"Target          : {target:.4f}")

print(f"Loss            : {best_loss:.8f}")



print("=" * 80)
print("Lab Complete")
print("=" * 80)





# ============================================================
# STEP 1. Library Import
# ============================================================

import time
import numpy as np
import matplotlib.pyplot as plt

from qiskit_algorithms.optimizers import COBYLA

# ============================================================
# STEP 2. Part 6 코드 준비
# ============================================================

"""
Part 6에서 다음 객체들이 이미 생성되어 있다고 가정한다.

theta
qc
predict()
target
shots
simulator
"""

print("="*80)
print("STEP 2. Common Objective Function")
print("="*80)

print("Part 6의 Objective Function 재사용")

# ============================================================
# STEP 3. COBYLA History
# ============================================================

print("\n")
print("="*80)
print("STEP 3. COBYLA History")
print("="*80)

cobyla_history = {

    "evaluation": [],

    "parameter": [],

    "prediction": [],

    "loss": [],

    "best_loss": []

}

# ============================================================
# STEP 4. COBYLA Objective Function
# ============================================================

print("\n")
print("="*80)
print("STEP 4. COBYLA Objective")
print("="*80)


def cobyla_objective(parameters):

    theta_value = float(parameters[0])

    prediction = predict(theta_value)

    loss = (prediction-target)**2

    evaluation = len(
        cobyla_history["evaluation"]
    ) + 1

    cobyla_history["evaluation"].append(
        evaluation
    )

    cobyla_history["parameter"].append(
        theta_value
    )

    cobyla_history["prediction"].append(
        prediction
    )

    cobyla_history["loss"].append(
        loss
    )

    current_best = min(
        cobyla_history["loss"]
    )

    cobyla_history["best_loss"].append(
        current_best
    )

    print(
        f"[{evaluation:03d}] "
        f"Theta={theta_value:8.4f} "
        f"Prediction={prediction:8.4f} "
        f"Loss={loss:10.6f}"
    )

    return float(loss)

# ============================================================
# STEP 5. Initial Parameter
# ============================================================

print("\n")
print("="*80)
print("STEP 5. Initial Parameter")
print("="*80)

initial_point = np.array([0.2])

initial_prediction = predict(
    initial_point[0]
)

initial_loss = (
    initial_prediction-target
)**2

print("Initial Parameter :", initial_point[0])

print("Initial Prediction :", initial_prediction)

print("Initial Loss :", initial_loss)

# ============================================================
# STEP 6. COBYLA 생성
# ============================================================

print("\n")
print("="*80)
print("STEP 6. COBYLA")
print("="*80)

optimizer = COBYLA(

    maxiter=100,

    rhobeg=1.0,

    tol=1e-6

)

print(optimizer)

# ============================================================
# STEP 7. Optimization
# ============================================================

print("\n")
print("="*80)
print("STEP 7. Optimization")
print("="*80)

start = time.perf_counter()

result = optimizer.minimize(

    fun=cobyla_objective,

    x0=initial_point

)

elapsed = time.perf_counter()-start

# ============================================================
# STEP 8. Optimization Result
# ============================================================

print("\n")
print("="*80)
print("STEP 8. Result")
print("="*80)

optimal_theta = float(result.x[0])

optimizer_loss = float(result.fun)

nfev = getattr(result,"nfev",None)

nit = getattr(result,"nit",None)

print("Optimal Theta :", optimal_theta)

print("Optimizer Loss :", optimizer_loss)

print("Function Evaluation :", nfev)

print("Iteration :", nit)

print("Elapsed Time :", elapsed)

# ============================================================
# STEP 9. Prediction Verification
# ============================================================

print("\n")
print("="*80)
print("STEP 9. Prediction Verification")
print("="*80)

final_prediction = predict(
    optimal_theta
)

verified_loss = (
    final_prediction-target
)**2

print("Prediction :", final_prediction)

print("Target :", target)

print("Verified Loss :", verified_loss)

# ============================================================
# STEP 10. Loss Curve
# ============================================================

plt.figure(figsize=(8,5))

plt.plot(

    cobyla_history["evaluation"],

    cobyla_history["loss"],

    marker="o",

    label="Loss"

)

plt.plot(

    cobyla_history["evaluation"],

    cobyla_history["best_loss"],

    linewidth=2,

    label="Best Loss"

)

plt.xlabel("Evaluation")

plt.ylabel("Loss")

plt.title("COBYLA Loss Curve")

plt.grid(True)

plt.legend()

plt.show()

# ============================================================
# STEP 11. Parameter Curve
# ============================================================

plt.figure(figsize=(8,5))

plt.plot(

    cobyla_history["evaluation"],

    cobyla_history["parameter"],

    marker="o"

)

plt.xlabel("Evaluation")

plt.ylabel("Theta")

plt.title("Parameter Update")

plt.grid(True)

plt.show()

# ============================================================
# STEP 12. Prediction Curve
# ============================================================

plt.figure(figsize=(8,5))

plt.plot(

    cobyla_history["evaluation"],

    cobyla_history["prediction"],

    marker="o"

)

plt.axhline(

    y=target,

    color="red",

    linestyle="--",

    label="Target"

)

plt.xlabel("Evaluation")

plt.ylabel("Prediction")

plt.title("Prediction Convergence")

plt.grid(True)

plt.legend()

plt.show()

# ============================================================
# STEP 13. Loss Landscape
# ============================================================

theta_space = np.linspace(
    0,
    2*np.pi,
    300
)

landscape = (
    np.cos(theta_space)-target
)**2

plt.figure(figsize=(9,6))

plt.plot(

    theta_space,

    landscape,

    label="Loss Landscape"

)

plt.scatter(

    cobyla_history["parameter"],

    cobyla_history["loss"],

    color="red",

    label="COBYLA"

)

plt.scatter(

    [initial_point[0]],

    [initial_loss],

    marker="s",

    s=100,

    label="Initial"

)

plt.scatter(

    [optimal_theta],

    [optimizer_loss],

    marker="*",

    s=200,

    label="Optimal"

)

plt.xlabel("Theta")

plt.ylabel("Loss")

plt.title("COBYLA Search Path")

plt.grid(True)

plt.legend()

plt.show()


print("="*80)
print("Lab Complete")
print("="*80)



"""
============================================================
Lab 6-3. SPSA Optimizer 적용
============================================================
"""





# ============================================================
# STEP 1. Library Import
# ============================================================

import time
import numpy as np
import matplotlib.pyplot as plt

from qiskit_algorithms.optimizers import SPSA

# ============================================================
# STEP 2. Part 6 코드 준비
# ============================================================

print("="*80)
print("STEP 2. Common Objective Function")
print("="*80)

print("Part 6 Objective Function 재사용")

# ============================================================
# STEP 3. SPSA History
# ============================================================

print("\n")
print("="*80)
print("STEP 3. SPSA History")
print("="*80)

spsa_history = {

    "evaluation": [],

    "parameter": [],

    "prediction": [],

    "loss": [],

    "best_loss": []

}

# ============================================================
# STEP 4. SPSA Objective Function
# ============================================================

print("\n")
print("="*80)
print("STEP 4. SPSA Objective")
print("="*80)

def spsa_objective(parameters):

    theta_value = float(parameters[0])

    prediction = predict(theta_value)

    loss = (prediction-target)**2

    evaluation = len(
        spsa_history["evaluation"]
    ) + 1

    spsa_history["evaluation"].append(
        evaluation
    )

    spsa_history["parameter"].append(
        theta_value
    )

    spsa_history["prediction"].append(
        prediction
    )

    spsa_history["loss"].append(
        loss
    )

    current_best = min(
        spsa_history["loss"]
    )

    spsa_history["best_loss"].append(
        current_best
    )

    print(
        f"[{evaluation:03d}] "
        f"Theta={theta_value:8.4f} "
        f"Prediction={prediction:8.4f} "
        f"Loss={loss:10.6f}"
    )

    return float(loss)

# ============================================================
# STEP 5. Initial Parameter
# ============================================================

print("\n")
print("="*80)
print("STEP 5. Initial Parameter")
print("="*80)

initial_point = np.array([0.2])

initial_prediction = predict(
    initial_point[0]
)

initial_loss = (
    initial_prediction-target
)**2

print("Initial Parameter :", initial_point[0])

print("Initial Prediction :", initial_prediction)

print("Initial Loss :", initial_loss)

# ============================================================
# STEP 6. SPSA 생성
# ============================================================

print("\n")
print("="*80)
print("STEP 6. SPSA")
print("="*80)

optimizer = SPSA(

    maxiter=100

)

print(optimizer)

# ============================================================
# STEP 7. Optimization
# ============================================================

print("\n")
print("="*80)
print("STEP 7. Optimization")
print("="*80)

start = time.perf_counter()

result = optimizer.minimize(

    fun=spsa_objective,

    x0=initial_point

)

elapsed = time.perf_counter()-start

# ============================================================
# STEP 8. Result
# ============================================================

print("\n")
print("="*80)
print("STEP 8. Result")
print("="*80)

optimal_theta = float(result.x[0])

optimizer_loss = float(result.fun)

nfev = getattr(result,"nfev",None)

nit = getattr(result,"nit",None)

print("Optimal Theta :", optimal_theta)

print("Optimizer Loss :", optimizer_loss)

print("Function Evaluation :", nfev)

print("Iteration :", nit)

print("Elapsed Time :", elapsed)

# ============================================================
# STEP 9. Prediction Verification
# ============================================================

print("\n")
print("="*80)
print("STEP 9. Prediction Verification")
print("="*80)

final_prediction = predict(
    optimal_theta
)

verified_loss = (
    final_prediction-target
)**2

print("Prediction :", final_prediction)

print("Target :", target)

print("Verified Loss :", verified_loss)

# ============================================================
# STEP 10. Loss Curve
# ============================================================

plt.figure(figsize=(8,5))

plt.plot(

    spsa_history["evaluation"],

    spsa_history["loss"],

    marker="o",

    label="Loss"

)

plt.plot(

    spsa_history["evaluation"],

    spsa_history["best_loss"],

    linewidth=2,

    label="Best Loss"

)

plt.xlabel("Evaluation")

plt.ylabel("Loss")

plt.title("SPSA Loss Curve")

plt.grid(True)

plt.legend()

plt.show()

# ============================================================
# STEP 11. Parameter Curve
# ============================================================

plt.figure(figsize=(8,5))

plt.plot(

    spsa_history["evaluation"],

    spsa_history["parameter"],

    marker="o"

)

plt.xlabel("Evaluation")

plt.ylabel("Theta")

plt.title("SPSA Parameter Update")

plt.grid(True)

plt.show()

# ============================================================
# STEP 12. Prediction Curve
# ============================================================

plt.figure(figsize=(8,5))

plt.plot(

    spsa_history["evaluation"],

    spsa_history["prediction"],

    marker="o"

)

plt.axhline(

    y=target,

    color="red",

    linestyle="--",

    label="Target"

)

plt.xlabel("Evaluation")

plt.ylabel("Prediction")

plt.title("Prediction Convergence")

plt.grid(True)

plt.legend()

plt.show()

# ============================================================
# STEP 13. Loss Landscape
# ============================================================

theta_space = np.linspace(
    0,
    2*np.pi,
    300
)

landscape = (
    np.cos(theta_space)-target
)**2

plt.figure(figsize=(9,6))

plt.plot(

    theta_space,

    landscape,

    label="Loss Landscape"

)

plt.scatter(

    spsa_history["parameter"],

    spsa_history["loss"],

    color="red",

    label="SPSA"

)

plt.scatter(

    [initial_point[0]],

    [initial_loss],

    marker="s",

    s=100,

    label="Initial"

)

plt.scatter(

    [optimal_theta],

    [optimizer_loss],

    marker="*",

    s=200,

    label="Optimal"

)

plt.xlabel("Theta")

plt.ylabel("Loss")

plt.title("SPSA Search Path")

plt.grid(True)

plt.legend()

plt.show()


print("="*80)
print("Lab Complete")
print("="*80)





"""
============================================================
Lab 6-4. Quantum Learning Visualization
============================================================
"""

# ============================================================
# STEP 1. Library Import
# ============================================================

import numpy as np
import matplotlib.pyplot as plt

# ============================================================
# STEP 2. History 확인
# ============================================================

print("=" * 80)
print("STEP 2. History")
print("=" * 80)

print("COBYLA Evaluation :", len(cobyla_history["evaluation"]))
print("SPSA Evaluation   :", len(spsa_history["evaluation"]))

# ============================================================
# STEP 3. COBYLA Loss Curve
# ============================================================

print("\n")
print("=" * 80)
print("STEP 3. COBYLA Loss Curve")
print("=" * 80)

plt.figure(figsize=(8,5))

plt.plot(

    cobyla_history["evaluation"],

    cobyla_history["loss"],

    marker="o",

    label="Loss"

)

plt.xlabel("Function Evaluation")

plt.ylabel("Loss")

plt.title("COBYLA Loss Curve")

plt.grid(True)

plt.legend()

plt.show()

# ============================================================
# STEP 4. SPSA Loss Curve
# ============================================================

print("\n")
print("=" * 80)
print("STEP 4. SPSA Loss Curve")
print("=" * 80)

plt.figure(figsize=(8,5))

plt.plot(

    spsa_history["evaluation"],

    spsa_history["loss"],

    marker="o",

    color="orange",

    label="Loss"

)

plt.xlabel("Function Evaluation")

plt.ylabel("Loss")

plt.title("SPSA Loss Curve")

plt.grid(True)

plt.legend()

plt.show()

# ============================================================
# STEP 5. Best Loss 비교
# ============================================================

print("\n")
print("=" * 80)
print("STEP 5. Best Loss Comparison")
print("=" * 80)

plt.figure(figsize=(9,5))

plt.plot(

    cobyla_history["evaluation"],

    cobyla_history["best_loss"],

    linewidth=3,

    label="COBYLA"

)

plt.plot(

    spsa_history["evaluation"],

    spsa_history["best_loss"],

    linewidth=3,

    label="SPSA"

)

plt.xlabel("Function Evaluation")

plt.ylabel("Best Loss")

plt.title("Best Loss Comparison")

plt.grid(True)

plt.legend()

plt.show()

# ============================================================
# STEP 6. Parameter Curve
# ============================================================

print("\n")
print("=" * 80)
print("STEP 6. Parameter Curve")
print("=" * 80)

plt.figure(figsize=(9,5))

plt.plot(

    cobyla_history["evaluation"],

    cobyla_history["parameter"],

    marker="o",

    label="COBYLA"

)

plt.plot(

    spsa_history["evaluation"],

    spsa_history["parameter"],

    marker="s",

    label="SPSA"

)

plt.xlabel("Function Evaluation")

plt.ylabel("Theta")

plt.title("Parameter Update")

plt.grid(True)

plt.legend()

plt.show()

# ============================================================
# STEP 7. Prediction Curve
# ============================================================

print("\n")
print("=" * 80)
print("STEP 7. Prediction Curve")
print("=" * 80)

plt.figure(figsize=(9,5))

plt.plot(

    cobyla_history["evaluation"],

    cobyla_history["prediction"],

    marker="o",

    label="COBYLA"

)

plt.plot(

    spsa_history["evaluation"],

    spsa_history["prediction"],

    marker="s",

    label="SPSA"

)

plt.axhline(

    y=target,

    color="red",

    linestyle="--",

    label="Target"

)

plt.xlabel("Function Evaluation")

plt.ylabel("Prediction")

plt.title("Prediction Comparison")

plt.grid(True)

plt.legend()

plt.show()

# ============================================================
# STEP 8. Loss Landscape
# ============================================================

print("\n")
print("=" * 80)
print("STEP 8. Loss Landscape")
print("=" * 80)

theta_space = np.linspace(

    0,

    2*np.pi,

    300

)

landscape = (

    np.cos(theta_space)

    -target

)**2

plt.figure(figsize=(10,6))

plt.plot(

    theta_space,

    landscape,

    linewidth=3,

    label="Loss Landscape"

)

plt.scatter(

    cobyla_history["parameter"],

    cobyla_history["loss"],

    color="blue",

    s=50,

    label="COBYLA"

)

plt.scatter(

    spsa_history["parameter"],

    spsa_history["loss"],

    color="red",

    s=50,

    label="SPSA"

)

plt.xlabel("Theta")

plt.ylabel("Loss")

plt.title("Loss Landscape")

plt.grid(True)

plt.legend()

plt.show()

# ============================================================
# STEP 9. Evaluation별 Loss 비교
# ============================================================

print("\n")
print("=" * 80)
print("STEP 9. Evaluation Comparison")
print("=" * 80)

max_eval = min(

    len(cobyla_history["loss"]),

    len(spsa_history["loss"])

)

plt.figure(figsize=(10,5))

plt.plot(

    range(max_eval),

    cobyla_history["loss"][:max_eval],

    label="COBYLA"

)

plt.plot(

    range(max_eval),

    spsa_history["loss"][:max_eval],

    label="SPSA"

)

plt.xlabel("Evaluation")

plt.ylabel("Loss")

plt.title("Loss Comparison")

plt.grid(True)

plt.legend()

plt.show()

# ============================================================
# STEP 10. 최종 결과 비교
# ============================================================

print("\n")
print("=" * 80)
print("STEP 10. Final Result")
print("=" * 80)

cobyla_final_parameter = cobyla_history["parameter"][-1]
cobyla_final_prediction = cobyla_history["prediction"][-1]
cobyla_final_loss = cobyla_history["best_loss"][-1]

spsa_final_parameter = spsa_history["parameter"][-1]
spsa_final_prediction = spsa_history["prediction"][-1]
spsa_final_loss = spsa_history["best_loss"][-1]

print("-"*80)

print("COBYLA")

print(f"Parameter  : {cobyla_final_parameter:.5f}")
print(f"Prediction : {cobyla_final_prediction:.5f}")
print(f"Loss       : {cobyla_final_loss:.8f}")

print("-"*80)

print("SPSA")

print(f"Parameter  : {spsa_final_parameter:.5f}")
print(f"Prediction : {spsa_final_prediction:.5f}")
print(f"Loss       : {spsa_final_loss:.8f}")

# ============================================================
# STEP 11. 결과 비교표 출력
# ============================================================

print("\n")
print("=" * 80)
print("STEP 11. Summary Table")
print("=" * 80)

print("{:<25}{:<15}{:<15}".format(

    "Item",

    "COBYLA",

    "SPSA"

))

print("-"*60)

print("{:<25}{:<15.5f}{:<15.5f}".format(

    "Final Parameter",

    cobyla_final_parameter,

    spsa_final_parameter

))

print("{:<25}{:<15.5f}{:<15.5f}".format(

    "Prediction",

    cobyla_final_prediction,

    spsa_final_prediction

))

print("{:<25}{:<15.8f}{:<15.8f}".format(

    "Best Loss",

    cobyla_final_loss,

    spsa_final_loss

))

print("{:<25}{:<15}{:<15}".format(

    "Evaluation",

    len(cobyla_history["evaluation"]),

    len(spsa_history["evaluation"])

))


print("="*80)
print("Visualization Complete")
print("="*80)
# Out:
# ================================================================================
# STEP 2. Parameterized Quantum Circuit
# ================================================================================
#         ┌───────┐ ░ ┌─┐
#      q: ┤ Ry(θ) ├─░─┤M├
#         └───────┘ ░ └╥┘
# meas: 1/═════════════╩═
#                      0
#
#
# ================================================================================
# STEP 3. Aer Simulator
# ================================================================================
# Backend : AerSimulator('aer_simulator')
# Shots   : 2048
#
#
# ================================================================================
# STEP 4. Prediction Function
# ================================================================================
#
#
# ================================================================================
# STEP 5. Prediction Test
# ================================================================================
# Theta : 0.000
# Prediction : 1.0000
# ----------------------------------------
# Theta : 1.571
# Prediction : -0.0176
# ----------------------------------------
# Theta : 3.142
# Prediction : -1.0000
# ----------------------------------------
#
#
# ================================================================================
# STEP 6. Target
# ================================================================================
# Target : -0.8
#
#
# ================================================================================
# STEP 7. Objective Function
# ================================================================================
# Objective Function 생성 완료
#
#
# ================================================================================
# STEP 8. Objective Function Test
# ================================================================================
# Theta      : 0.100
# Prediction : 0.9951
# Loss       : 3.225953
# --------------------------------------------------
# Theta      : 1.000
# Prediction : 0.5596
# Loss       : 1.767030
# --------------------------------------------------
# Theta      : 2.500
# Prediction : -0.8018
# Loss       : 0.000374
# --------------------------------------------------
#
#
# ================================================================================
# STEP 9. Parameter Sweep
# ================================================================================
# Parameter Sweep 완료
# Total Samples : 30
# ================================================================================
# STEP 12. Best Parameter
# ================================================================================
# Best Theta      : 3.6832
# Prediction      : -0.8643
# Target          : -0.8000
# Loss            : 0.00364231
# ================================================================================
# Lab Complete
# ================================================================================
# ================================================================================
# STEP 2. Common Objective Function
# ================================================================================
# Part 6의 Objective Function 재사용
#
#
# ================================================================================
# STEP 3. COBYLA History
# ================================================================================
#
#
# ================================================================================
# STEP 4. COBYLA Objective
# ================================================================================
#
#
# ================================================================================
# STEP 5. Initial Parameter
# ================================================================================
# Initial Parameter : 0.2
# Initial Prediction : 0.9736328125
# Initial Loss : 3.14577335357666
#
#
# ================================================================================
# STEP 6. COBYLA
# ================================================================================
# <qiskit_algorithms.optimizers.cobyla.COBYLA object at 0x110f14c20>
#
#
# ================================================================================
# STEP 7. Optimization
# ================================================================================
# [001] Theta=  0.2000 Prediction=  0.9795 Loss=  3.166592
# [002] Theta=  1.2000 Prediction=  0.3740 Loss=  1.378331
# [003] Theta=  2.2000 Prediction= -0.5869 Loss=  0.045406
# [004] Theta=  4.2000 Prediction= -0.4932 Loss=  0.094148
# [005] Theta=  1.2000 Prediction=  0.3867 Loss=  1.408301
# [006] Theta=  2.7000 Prediction= -0.9072 Loss=  0.011498
# [007] Theta=  2.9500 Prediction= -0.9844 Loss=  0.033994
# [008] Theta=  2.6000 Prediction= -0.8594 Loss=  0.003525
# [009] Theta=  2.4000 Prediction= -0.7461 Loss=  0.002906
# [010] Theta=  2.3000 Prediction= -0.6699 Loss=  0.016920
# [011] Theta=  2.5000 Prediction= -0.8340 Loss=  0.001155
# [012] Theta=  2.6000 Prediction= -0.8506 Loss=  0.002559
# [013] Theta=  2.4500 Prediction= -0.7881 Loss=  0.000142
# [014] Theta=  2.3500 Prediction= -0.6992 Loss=  0.010157
# [015] Theta=  2.5000 Prediction= -0.7949 Loss=  0.000026
# [016] Theta=  2.5250 Prediction= -0.8057 Loss=  0.000032
# [017] Theta=  2.4950 Prediction= -0.8135 Loss=  0.000182
# [018] Theta=  2.5100 Prediction= -0.7920 Loss=  0.000064
# [019] Theta=  2.4950 Prediction= -0.7910 Loss=  0.000081
# [020] Theta=  2.5013 Prediction= -0.8076 Loss=  0.000058
# [021] Theta=  2.4975 Prediction= -0.7793 Loss=  0.000429
# [022] Theta=  2.5010 Prediction= -0.8086 Loss=  0.000074
# [023] Theta=  2.4990 Prediction= -0.7998 Loss=  0.000000
# [024] Theta=  2.4980 Prediction= -0.7861 Loss=  0.000192
# [025] Theta=  2.4995 Prediction= -0.8027 Loss=  0.000007
# [026] Theta=  2.4988 Prediction= -0.8135 Loss=  0.000182
# [027] Theta=  2.4991 Prediction= -0.8018 Loss=  0.000003
# [028] Theta=  2.4989 Prediction= -0.8086 Loss=  0.000074
# [029] Theta=  2.4990 Prediction= -0.7959 Loss=  0.000017
# [030] Theta=  2.4990 Prediction= -0.7832 Loss=  0.000282
# [031] Theta=  2.4990 Prediction= -0.8203 Loss=  0.000413
# [032] Theta=  2.4990 Prediction= -0.8164 Loss=  0.000269
# [033] Theta=  2.4990 Prediction= -0.8076 Loss=  0.000058
# [034] Theta=  2.4990 Prediction= -0.7773 Loss=  0.000513
# [035] Theta=  2.4990 Prediction= -0.7891 Loss=  0.000120
# [036] Theta=  2.4990 Prediction= -0.7803 Loss=  0.000389
#
#
# ================================================================================
# STEP 8. Result
# ================================================================================
# Optimal Theta : 2.499
# Optimizer Loss : 3.8146972656267345e-08
# Function Evaluation : 36
# Iteration : None
# Elapsed Time : 4.000643208157271
#
#
# ================================================================================
# STEP 9. Prediction Verification
# ================================================================================
# Prediction : -0.8232421875
# Target : -0.8
# Verified Loss : 0.0005401992797851541
# ================================================================================
# Lab Complete
# ================================================================================
# ================================================================================
# STEP 2. Common Objective Function
# ================================================================================
# Part 6 Objective Function 재사용
#
#
# ================================================================================
# STEP 3. SPSA History
# ================================================================================
#
#
# ================================================================================
# STEP 4. SPSA Objective
# ================================================================================
#
#
# ================================================================================
# STEP 5. Initial Parameter
# ================================================================================
# Initial Parameter : 0.2
# Initial Prediction : 0.974609375
# Initial Loss : 3.149238433837891
#
#
# ================================================================================
# STEP 6. SPSA
# ================================================================================
# <qiskit_algorithms.optimizers.spsa.SPSA object at 0x1112b9010>
#
#
# ================================================================================
# STEP 7. Optimization
# ================================================================================
# [001] Theta=  0.4000 Prediction=  0.9326 Loss=  3.001962
# [002] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [003] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [004] Theta=  0.4000 Prediction=  0.9248 Loss=  2.974951
# [005] Theta=  0.4000 Prediction=  0.9131 Loss=  2.934663
# [006] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [007] Theta=  0.4000 Prediction=  0.9229 Loss=  2.968218
# [008] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [009] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [010] Theta=  0.4000 Prediction=  0.9453 Loss=  3.046116
# [011] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [012] Theta=  0.4000 Prediction=  0.9336 Loss=  3.005347
# [013] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [014] Theta=  0.4000 Prediction=  0.9297 Loss=  2.991819
# [015] Theta=  0.4000 Prediction=  0.9141 Loss=  2.938010
# [016] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [017] Theta=  0.4000 Prediction=  0.9180 Loss=  2.951417
# [018] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [019] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [020] Theta=  0.4000 Prediction=  0.9316 Loss=  2.998579
# [021] Theta=  0.4000 Prediction=  0.9355 Loss=  3.012123
# [022] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [023] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [024] Theta=  0.4000 Prediction=  0.9160 Loss=  2.944710
# [025] Theta=  0.4000 Prediction=  0.9141 Loss=  2.938010
# [026] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [027] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [028] Theta=  0.4000 Prediction=  0.9277 Loss=  2.985066
# [029] Theta=  0.4000 Prediction=  0.9121 Loss=  2.931319
# [030] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [031] Theta=  0.4000 Prediction=  0.9141 Loss=  2.938010
# [032] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [033] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [034] Theta=  0.4000 Prediction=  0.9072 Loss=  2.914623
# [035] Theta=  0.4000 Prediction=  0.9277 Loss=  2.985066
# [036] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [037] Theta=  0.4000 Prediction=  0.9268 Loss=  2.981693
# [038] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [039] Theta=  0.4000 Prediction=  0.9248 Loss=  2.974951
# [040] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [041] Theta=  0.4000 Prediction=  0.9258 Loss=  2.978321
# [042] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [043] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [044] Theta=  0.4000 Prediction=  0.9238 Loss=  2.971583
# [045] Theta=  0.4000 Prediction=  0.9043 Loss=  2.904628
# [046] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [047] Theta=  0.4000 Prediction=  0.9258 Loss=  2.978321
# [048] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [049] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [050] Theta=  0.4000 Prediction=  0.9160 Loss=  2.944710
# [051] Theta=  0.4000 Prediction=  0.9248 Loss=  2.974951
# [052] Theta=  0.0000 Prediction=  1.0000 Loss=  3.240000
# [053] Theta=  0.6253 Prediction=  0.8076 Loss=  2.584433
# [054] Theta=  0.9982 Prediction=  0.5391 Loss=  1.793088
# [055] Theta=  2.2813 Prediction= -0.6611 Loss=  0.019284
# [056] Theta=  1.9233 Prediction= -0.3301 Loss=  0.220827
# [057] Theta=  2.5445 Prediction= -0.8105 Loss=  0.000111
# [058] Theta=  2.1967 Prediction= -0.5840 Loss=  0.046663
# [059] Theta=  2.5942 Prediction= -0.8301 Loss=  0.000905
# [060] Theta=  2.2543 Prediction= -0.6523 Loss=  0.021802
# [061] Theta=  2.6127 Prediction= -0.8926 Loss=  0.008571
# [062] Theta=  2.2789 Prediction= -0.6592 Loss=  0.019830
# [063] Theta=  2.6207 Prediction= -0.8418 Loss=  0.001747
# [064] Theta=  2.2921 Prediction= -0.6553 Loss=  0.020946
# [065] Theta=  2.3110 Prediction= -0.6455 Loss=  0.023868
# [066] Theta=  2.6352 Prediction= -0.8760 Loss=  0.005772
# [067] Theta=  2.3276 Prediction= -0.6689 Loss=  0.017175
# [068] Theta=  2.6480 Prediction= -0.8848 Loss=  0.007185
# [069] Theta=  2.3370 Prediction= -0.6826 Loss=  0.013779
# [070] Theta=  2.6540 Prediction= -0.8643 Loss=  0.004129
# [071] Theta=  2.3455 Prediction= -0.7197 Loss=  0.006444
# [072] Theta=  2.6595 Prediction= -0.8848 Loss=  0.007185
# [073] Theta=  2.3464 Prediction= -0.7090 Loss=  0.008284
# [074] Theta=  2.6576 Prediction= -0.8896 Loss=  0.008037
# [075] Theta=  2.6565 Prediction= -0.9053 Loss=  0.011082
# [076] Theta=  2.3478 Prediction= -0.6934 Loss=  0.011372
# [077] Theta=  2.3492 Prediction= -0.7051 Loss=  0.009010
# [078] Theta=  2.6556 Prediction= -0.8760 Loss=  0.005772
# [079] Theta=  2.3522 Prediction= -0.7139 Loss=  0.007419
# [080] Theta=  2.6565 Prediction= -0.8896 Loss=  0.008037
# [081] Theta=  2.6551 Prediction= -0.8750 Loss=  0.005625
# [082] Theta=  2.3528 Prediction= -0.6865 Loss=  0.012877
# [083] Theta=  2.6584 Prediction= -0.8828 Loss=  0.006858
# [084] Theta=  2.3579 Prediction= -0.6953 Loss=  0.010959
# [085] Theta=  2.6598 Prediction= -0.8838 Loss=  0.007021
# [086] Theta=  2.3611 Prediction= -0.6934 Loss=  0.011372
# [087] Theta=  2.6614 Prediction= -0.8906 Loss=  0.008213
# [088] Theta=  2.3643 Prediction= -0.7090 Loss=  0.008284
# [089] Theta=  2.3651 Prediction= -0.7432 Loss=  0.003230
# [090] Theta=  2.6606 Prediction= -0.8984 Loss=  0.009690
# [091] Theta=  2.3625 Prediction= -0.7070 Loss=  0.008643
# [092] Theta=  2.6566 Prediction= -0.8936 Loss=  0.008752
# [093] Theta=  2.3631 Prediction= -0.7227 Loss=  0.005982
# [094] Theta=  2.6558 Prediction= -0.8896 Loss=  0.008037
# [095] Theta=  2.6542 Prediction= -0.8965 Loss=  0.009309
# [096] Theta=  2.3627 Prediction= -0.7061 Loss=  0.008826
# [097] Theta=  2.3631 Prediction= -0.7100 Loss=  0.008107
# [098] Theta=  2.6533 Prediction= -0.9004 Loss=  0.010078
# [099] Theta=  2.3628 Prediction= -0.7236 Loss=  0.005832
# [100] Theta=  2.6518 Prediction= -0.8691 Loss=  0.004780
# [101] Theta=  2.3639 Prediction= -0.7090 Loss=  0.008284
# [102] Theta=  2.6517 Prediction= -0.8730 Loss=  0.005336
# [103] Theta=  2.6525 Prediction= -0.8799 Loss=  0.006381
# [104] Theta=  2.3657 Prediction= -0.6846 Loss=  0.013324
# [105] Theta=  2.3693 Prediction= -0.7148 Loss=  0.007252
# [106] Theta=  2.6550 Prediction= -0.8789 Loss=  0.006226
# [107] Theta=  2.6550 Prediction= -0.8701 Loss=  0.004916
# [108] Theta=  2.3703 Prediction= -0.7588 Loss=  0.001698
# [109] Theta=  2.6531 Prediction= -0.8936 Loss=  0.008752
# [110] Theta=  2.3694 Prediction= -0.6934 Loss=  0.011372
# [111] Theta=  2.3710 Prediction= -0.7256 Loss=  0.005537
# [112] Theta=  2.6537 Prediction= -0.8691 Loss=  0.004780
# [113] Theta=  2.6536 Prediction= -0.8867 Loss=  0.007520
# [114] Theta=  2.3717 Prediction= -0.7285 Loss=  0.005110
# [115] Theta=  2.6522 Prediction= -0.8770 Loss=  0.005922
# [116] Theta=  2.3712 Prediction= -0.7080 Loss=  0.008463
# [117] Theta=  2.6528 Prediction= -0.8838 Loss=  0.007021
# [118] Theta=  2.3726 Prediction= -0.7148 Loss=  0.007252
# [119] Theta=  2.3731 Prediction= -0.7256 Loss=  0.005537
# [120] Theta=  2.6525 Prediction= -0.8701 Loss=  0.004916
# [121] Theta=  2.3738 Prediction= -0.7402 Loss=  0.003572
# [122] Theta=  2.6523 Prediction= -0.8711 Loss=  0.005054
# [123] Theta=  2.6514 Prediction= -0.8887 Loss=  0.007863
# [124] Theta=  2.3736 Prediction= -0.7100 Loss=  0.008107
# [125] Theta=  2.3741 Prediction= -0.6973 Loss=  0.010554
# [126] Theta=  2.6511 Prediction= -0.8809 Loss=  0.006538
# [127] Theta=  2.6522 Prediction= -0.8896 Loss=  0.008037
# [128] Theta=  2.3759 Prediction= -0.7246 Loss=  0.005684
# [129] Theta=  2.6510 Prediction= -0.8750 Loss=  0.005625
# [130] Theta=  2.3754 Prediction= -0.7236 Loss=  0.005832
# [131] Theta=  2.6507 Prediction= -0.8828 Loss=  0.006858
# [132] Theta=  2.3758 Prediction= -0.7324 Loss=  0.004567
# [133] Theta=  2.6496 Prediction= -0.8936 Loss=  0.008752
# [134] Theta=  2.3753 Prediction= -0.7285 Loss=  0.005110
# [135] Theta=  2.6479 Prediction= -0.8877 Loss=  0.007690
# [136] Theta=  2.3744 Prediction= -0.6914 Loss=  0.011793
# [137] Theta=  2.3761 Prediction= -0.7256 Loss=  0.005537
# [138] Theta=  2.6491 Prediction= -0.8848 Loss=  0.007185
# [139] Theta=  2.6482 Prediction= -0.8633 Loss=  0.004005
# [140] Theta=  2.3759 Prediction= -0.7246 Loss=  0.005684
# [141] Theta=  2.6485 Prediction= -0.8789 Loss=  0.006226
# [142] Theta=  2.3767 Prediction= -0.7217 Loss=  0.006134
# [143] Theta=  2.3770 Prediction= -0.7510 Loss=  0.002403
# [144] Theta=  2.6481 Prediction= -0.8809 Loss=  0.006538
# [145] Theta=  2.3759 Prediction= -0.7227 Loss=  0.005982
# [146] Theta=  2.6465 Prediction= -0.8740 Loss=  0.005479
# [147] Theta=  2.6463 Prediction= -0.8721 Loss=  0.005194
# [148] Theta=  2.3764 Prediction= -0.7275 Loss=  0.005251
# [149] Theta=  2.6461 Prediction= -0.8701 Loss=  0.004916
# [150] Theta=  2.3767 Prediction= -0.7188 Loss=  0.006602
# [151] Theta=  2.6464 Prediction= -0.8926 Loss=  0.008571
# [152] Theta=  2.3775 Prediction= -0.7109 Loss=  0.007932
# [153] Theta=  2.3775 Prediction= -0.7383 Loss=  0.003809
# [154] Theta=  2.6459 Prediction= -0.8838 Loss=  0.007021
# [155] Theta=  2.6446 Prediction= -0.8887 Loss=  0.007863
# [156] Theta=  2.3768 Prediction= -0.7441 Loss=  0.003120
# [157] Theta=  2.6429 Prediction= -0.8809 Loss=  0.006538
# [158] Theta=  2.3755 Prediction= -0.7383 Loss=  0.003809
# [159] Theta=  2.6418 Prediction= -0.8672 Loss=  0.004514
# [160] Theta=  2.3749 Prediction= -0.7217 Loss=  0.006134
# [161] Theta=  2.3757 Prediction= -0.7168 Loss=  0.006923
# [162] Theta=  2.6420 Prediction= -0.8682 Loss=  0.004646
# [163] Theta=  2.6425 Prediction= -0.8867 Loss=  0.007520
# [164] Theta=  2.3766 Prediction= -0.7227 Loss=  0.005982
# [165] Theta=  2.6418 Prediction= -0.8789 Loss=  0.006226
# [166] Theta=  2.3764 Prediction= -0.7354 Loss=  0.004179
# [167] Theta=  2.3760 Prediction= -0.7441 Loss=  0.003120
# [168] Theta=  2.6409 Prediction= -0.8555 Loss=  0.003077
# [169] Theta=  2.3762 Prediction= -0.7314 Loss=  0.004700
# [170] Theta=  2.6407 Prediction= -0.8555 Loss=  0.003077
# [171] Theta=  2.3769 Prediction= -0.7090 Loss=  0.008284
# [172] Theta=  2.6410 Prediction= -0.8887 Loss=  0.007863
# [173] Theta=  2.6409 Prediction= -0.8779 Loss=  0.006073
# [174] Theta=  2.3772 Prediction= -0.7100 Loss=  0.008107
# [175] Theta=  2.6413 Prediction= -0.8828 Loss=  0.006858
# [176] Theta=  2.3781 Prediction= -0.7305 Loss=  0.004835
# [177] Theta=  2.6405 Prediction= -0.8887 Loss=  0.007863
# [178] Theta=  2.3777 Prediction= -0.7246 Loss=  0.005684
# [179] Theta=  2.6397 Prediction= -0.8838 Loss=  0.007021
# [180] Theta=  2.3773 Prediction= -0.7324 Loss=  0.004567
# [181] Theta=  2.6387 Prediction= -0.8945 Loss=  0.008936
# [182] Theta=  2.3768 Prediction= -0.7246 Loss=  0.005684
# [183] Theta=  2.6376 Prediction= -0.8770 Loss=  0.005922
# [184] Theta=  2.3760 Prediction= -0.6992 Loss=  0.010157
# [185] Theta=  2.6386 Prediction= -0.8750 Loss=  0.005625
# [186] Theta=  2.3774 Prediction= -0.7109 Loss=  0.007932
# [187] Theta=  2.3783 Prediction= -0.7490 Loss=  0.002599
# [188] Theta=  2.6391 Prediction= -0.8672 Loss=  0.004514
# [189] Theta=  2.3779 Prediction= -0.7275 Loss=  0.005251
# [190] Theta=  2.6384 Prediction= -0.8887 Loss=  0.007863
# [191] Theta=  2.3774 Prediction= -0.7617 Loss=  0.001465
# [192] Theta=  2.6375 Prediction= -0.8955 Loss=  0.009122
# [193] Theta=  2.6352 Prediction= -0.8828 Loss=  0.006858
# [194] Theta=  2.3755 Prediction= -0.7461 Loss=  0.002906
# [195] Theta=  2.6339 Prediction= -0.8701 Loss=  0.004916
# [196] Theta=  2.3746 Prediction= -0.6973 Loss=  0.010554
# [197] Theta=  2.3763 Prediction= -0.7227 Loss=  0.005982
# [198] Theta=  2.6353 Prediction= -0.8799 Loss=  0.006381
# [199] Theta=  2.3764 Prediction= -0.7285 Loss=  0.005110
# [200] Theta=  2.6350 Prediction= -0.8691 Loss=  0.004780
# [201] Theta=  2.3766 Prediction= -0.7305 Loss=  0.004835
# [202] Theta=  2.6349 Prediction= -0.8740 Loss=  0.005479
# [203] Theta=  2.3766 Prediction= -0.7451 Loss=  0.003012
# [204] Theta=  2.6346 Prediction= -0.8857 Loss=  0.007352
# [205] Theta=  2.6333 Prediction= -0.8848 Loss=  0.007185
# [206] Theta=  2.3756 Prediction= -0.7324 Loss=  0.004567
# [207] Theta=  2.3751 Prediction= -0.7051 Loss=  0.009010
# [208] Theta=  2.6324 Prediction= -0.8672 Loss=  0.004514
# [209] Theta=  2.3765 Prediction= -0.7422 Loss=  0.003342
# [210] Theta=  2.6334 Prediction= -0.8828 Loss=  0.006858
# [211] Theta=  2.3757 Prediction= -0.7295 Loss=  0.004971
# [212] Theta=  2.6323 Prediction= -0.8799 Loss=  0.006381
# [213] Theta=  2.3755 Prediction= -0.7227 Loss=  0.005982
# [214] Theta=  2.6318 Prediction= -0.8936 Loss=  0.008752
# [215] Theta=  2.3750 Prediction= -0.7236 Loss=  0.005832
# [216] Theta=  2.6310 Prediction= -0.8955 Loss=  0.009122
# [217] Theta=  2.3743 Prediction= -0.6992 Loss=  0.010157
# [218] Theta=  2.6300 Prediction= -0.8643 Loss=  0.004129
# [219] Theta=  2.3760 Prediction= -0.7188 Loss=  0.006602
# [220] Theta=  2.6313 Prediction= -0.8662 Loss=  0.004384
# [221] Theta=  2.6317 Prediction= -0.8594 Loss=  0.003525
# [222] Theta=  2.3767 Prediction= -0.7393 Loss=  0.003690
# [223] Theta=  2.6316 Prediction= -0.8652 Loss=  0.004256
# [224] Theta=  2.3768 Prediction= -0.7188 Loss=  0.006602
# [225] Theta=  2.6321 Prediction= -0.8584 Loss=  0.003410
# [226] Theta=  2.3776 Prediction= -0.7256 Loss=  0.005537
# [227] Theta=  2.3782 Prediction= -0.6973 Loss=  0.010554
# [228] Theta=  2.6324 Prediction= -0.8691 Loss=  0.004780
# [229] Theta=  2.3798 Prediction= -0.7080 Loss=  0.008463
# [230] Theta=  2.6337 Prediction= -0.8652 Loss=  0.004256
# [231] Theta=  2.3810 Prediction= -0.7168 Loss=  0.006923
# [232] Theta=  2.6346 Prediction= -0.8623 Loss=  0.003882
# [233] Theta=  2.6352 Prediction= -0.8633 Loss=  0.004005
# [234] Theta=  2.3818 Prediction= -0.7080 Loss=  0.008463
# [235] Theta=  2.6361 Prediction= -0.8896 Loss=  0.008037
# [236] Theta=  2.3830 Prediction= -0.7266 Loss=  0.005393
# [237] Theta=  2.6353 Prediction= -0.8887 Loss=  0.007863
# [238] Theta=  2.3825 Prediction= -0.7021 Loss=  0.009575
# [239] Theta=  2.6356 Prediction= -0.8779 Loss=  0.006073
# [240] Theta=  2.3831 Prediction= -0.6963 Loss=  0.010756
# [241] Theta=  2.3843 Prediction= -0.7383 Loss=  0.003809
# [242] Theta=  2.6366 Prediction= -0.8564 Loss=  0.003186
# [243] Theta=  2.6366 Prediction= -0.8926 Loss=  0.008571
# [244] Theta=  2.3846 Prediction= -0.7207 Loss=  0.006288
# [245] Theta=  2.3842 Prediction= -0.6992 Loss=  0.010157
# [246] Theta=  2.6359 Prediction= -0.8740 Loss=  0.005479
# [247] Theta=  2.3854 Prediction= -0.7266 Loss=  0.005393
# [248] Theta=  2.6369 Prediction= -0.8594 Loss=  0.003525
# [249] Theta=  2.3860 Prediction= -0.7256 Loss=  0.005537
# [250] Theta=  2.6372 Prediction= -0.8916 Loss=  0.008391
# [251] Theta=  2.5109 Prediction= -0.8291 Loss=  0.000847
#
#
# ================================================================================
# STEP 8. Result
# ================================================================================
# Optimal Theta : 2.5109197669476635
# Optimizer Loss : 0.0008469009399414036
# Function Evaluation : 200
# Iteration : 100
# Elapsed Time : 21.685808083973825
#
#
# ================================================================================
# STEP 9. Prediction Verification
# ================================================================================
# Prediction : -0.7958984375
# Target : -0.8
# Verified Loss : 1.6822814941406613e-05
# ================================================================================
# Lab Complete
# ================================================================================
# ================================================================================
# STEP 2. History
# ================================================================================
# COBYLA Evaluation : 36
# SPSA Evaluation   : 251
#
#
# ================================================================================
# STEP 3. COBYLA Loss Curve
# ================================================================================
# ================================================================================
# STEP 4. SPSA Loss Curve
# ================================================================================
# ================================================================================
# STEP 5. Best Loss Comparison
# ================================================================================
# ================================================================================
# STEP 6. Parameter Curve
# ================================================================================
# ================================================================================
# STEP 7. Prediction Curve
# ================================================================================
# ================================================================================
# STEP 8. Loss Landscape
# ================================================================================
# ================================================================================
# STEP 9. Evaluation Comparison
# ================================================================================
# ================================================================================
# STEP 10. Final Result
# ================================================================================
# --------------------------------------------------------------------------------
# COBYLA
# Parameter  : 2.49900
# Prediction : -0.78027
# Loss       : 0.00000004
# --------------------------------------------------------------------------------
# SPSA
# Parameter  : 2.51092
# Prediction : -0.82910
# Loss       : 0.00011124
#
#
# ================================================================================
# STEP 11. Summary Table
# ================================================================================
# Item                     COBYLA         SPSA
# ------------------------------------------------------------
# Final Parameter          2.49900        2.51092
# Prediction               -0.78027       -0.82910
# Best Loss                0.00000004     0.00011124
# Evaluation               36             251
# ================================================================================
# Visualization Complete
# ================================================================================
