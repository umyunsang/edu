# %% [markdown]
# <a href="https://colab.research.google.com/github/umyunsang/edu/blob/main/ComputerScience/03_ai-ml-data/quantum-ml/1.quantum-ml-overview/qml-circuit/day11_1_1_feature_map_circuit_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # 1-1.py
#
# Colab-ready practice notebook converted from the shared Google Drive Python script.

# %%
from qiskit import QuantumCircuit
import matplotlib.pyplot as plt


x1 = 0.5
x2 = 1.2

qc = QuantumCircuit(2)

qc.h(0)
qc.h(1)

qc.ry(x1, 0)
qc.ry(x2, 1)

qc.cx(0, 1)

qc.rz(x1 * x2, 1)

qc.draw("mpl")
plt.show()
