# %% [markdown]
# <a href="https://colab.research.google.com/github/umyunsang/edu/blob/main/ComputerScience/03_ai-ml-data/quantum-ml/02.circuits-and-encoding/01.quantum-circuits-and-qml/04_composite_gate_measurement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Day11 복합 게이트 측정 실습
# 구글 드라이브 공유 실습 소스를 Colab 실행용 노트북으로 변환한 자료입니다.

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram

import matplotlib.pyplot as plt

qc = QuantumCircuit(2)

qc.h(0)

qc.rx(0.8,0)

qc.ry(1.2,1)

qc.cx(0,1)

qc.rz(0.6,0)

qc.x(1)

qc.measure_all()

sim = AerSimulator()

job = sim.run(qc,shots=1000)

result = job.result()

counts = result.get_counts()
print(counts)

plot_histogram(counts)
plt.show()
# Out:
# {'01': 349, '11': 159, '10': 347, '00': 145}
