# %% [markdown]
# # Day09 특성 인코딩 얽힘 회로 실습
# 구글 드라이브 공유 실습 소스를 Colab 실행용 노트북으로 변환한 자료입니다.

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt
import numpy as np

qc = QuantumCircuit(2)

age = np.pi / 3
salary = np.pi / 4

qc.ry(age, 0)
qc.ry(salary, 1)

qc.h(0)
qc.h(1)

qc.rz(np.pi/6,0)
qc.rx(np.pi/8,1)

qc.cx(0,1)

qc.ry(np.pi/5,0)
qc.rz(np.pi/7,1)

qc.draw("mpl")

qc.measure_all()

sim = AerSimulator()

job = sim.run(qc, shots=1000)

result = job.result()

counts = result.get_counts()

print(counts)
print(qc.count_ops())
print(qc.depth())
print(qc)

plot_histogram(counts)
plt.show()
# Out:
# {'01': 139, '11': 79, '10': 148, '00': 634}
# OrderedDict({'ry': 3, 'h': 2, 'rz': 2, 'measure': 2, 'rx': 1, 'cx': 1, 'barrier': 1})
# 6
#         ┌─────────┐┌───┐┌─────────┐     ┌─────────┐ ░ ┌─┐
#    q_0: ┤ Ry(π/3) ├┤ H ├┤ Rz(π/6) ├──■──┤ Ry(π/5) ├─░─┤M├───
#         ├─────────┤├───┤├─────────┤┌─┴─┐├─────────┤ ░ └╥┘┌─┐
#    q_1: ┤ Ry(π/4) ├┤ H ├┤ Rx(π/8) ├┤ X ├┤ Rz(π/7) ├─░──╫─┤M├
#         └─────────┘└───┘└─────────┘└───┘└─────────┘ ░  ║ └╥┘
# meas: 2/═══════════════════════════════════════════════╩══╩═
#                                                        0  1
