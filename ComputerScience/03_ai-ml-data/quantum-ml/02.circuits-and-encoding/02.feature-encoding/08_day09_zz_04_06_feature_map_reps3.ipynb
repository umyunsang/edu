# %% [markdown]
# # ZZ-4-6.py
#
# Colab-ready practice notebook converted from the shared Google Drive Python source.

# %%
from qiskit.circuit.library import zz_feature_map

feature_map = zz_feature_map(
    feature_dimension=2,
    reps=3
)

print(feature_map)
feature_map.count_ops()

feature_map.draw("mpl")

from matplotlib import pyplot as plt
plt.show()
# Out:
#    ┌───┐┌───────────┐                                          ┌───┐»
# 0: ┤ H ├┤ P(2*x[0]) ├──■────────────────────────────────────■──┤ H ├»
#    ├───┤├───────────┤┌─┴─┐┌──────────────────────────────┐┌─┴─┐├───┤»
# 1: ┤ H ├┤ P(2*x[1]) ├┤ X ├┤ P((-π + x[0])*(-π + x[1])*2) ├┤ X ├┤ H ├»
#    └───┘└───────────┘└───┘└──────────────────────────────┘└───┘└───┘»
# «   ┌───────────┐                                          ┌───┐┌───────────┐»
# «0: ┤ P(2*x[0]) ├──■────────────────────────────────────■──┤ H ├┤ P(2*x[0]) ├»
# «   ├───────────┤┌─┴─┐┌──────────────────────────────┐┌─┴─┐├───┤├───────────┤»
# «1: ┤ P(2*x[1]) ├┤ X ├┤ P((-π + x[0])*(-π + x[1])*2) ├┤ X ├┤ H ├┤ P(2*x[1]) ├»
# «   └───────────┘└───┘└──────────────────────────────┘└───┘└───┘└───────────┘»
# «
# «0: ──■────────────────────────────────────■──
# «   ┌─┴─┐┌──────────────────────────────┐┌─┴─┐
# «1: ┤ X ├┤ P((-π + x[0])*(-π + x[1])*2) ├┤ X ├
# «   └───┘└──────────────────────────────┘└───┘
