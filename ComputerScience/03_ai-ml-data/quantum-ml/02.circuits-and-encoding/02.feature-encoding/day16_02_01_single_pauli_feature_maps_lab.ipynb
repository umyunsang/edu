# %% [markdown]
# <a href="https://colab.research.google.com/github/umyunsang/edu/blob/main/ComputerScience/03_ai-ml-data/quantum-ml/02.circuits-and-encoding/02.feature-encoding/day16_02_01_single_pauli_feature_maps_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day16 single-Pauli feature map 비교 실습
#
# - Source: Google Drive `Day16/2-1.py`
# - Runtime: Google Colab recommended. Do not install or execute dependencies locally for sync validation.

# %%
from qiskit.circuit.library import pauli_feature_map

feature_dim = 3

single_pauli_maps = {
    "X Mapping": pauli_feature_map(
        feature_dimension=feature_dim,
        reps=1,
        paulis=["X"]
    ),
    "Y Mapping": pauli_feature_map(
        feature_dimension=feature_dim,
        reps=1,
        paulis=["Y"]
    ),
    "Z Mapping": pauli_feature_map(
        feature_dimension=feature_dim,
        reps=1,
        paulis=["Z"]
    )
}

for name, fmap in single_pauli_maps.items():
    print("=" * 60)
    print(name)
    print(fmap.decompose())
    print("Depth:", fmap.decompose().depth())
    print("Gate count:", fmap.decompose().count_ops())
# Out:
# ============================================================
# X Mapping
#    ┌────────────┐┌────────────┐┌───────────────┐┌────────────┐
# 0: ┤ U(π/2,0,π) ├┤ U(π/2,0,π) ├┤ U(0,0,2*x[0]) ├┤ U(π/2,0,π) ├
#    ├────────────┤├────────────┤├───────────────┤├────────────┤
# 1: ┤ U(π/2,0,π) ├┤ U(π/2,0,π) ├┤ U(0,0,2*x[1]) ├┤ U(π/2,0,π) ├
#    ├────────────┤├────────────┤├───────────────┤├────────────┤
# 2: ┤ U(π/2,0,π) ├┤ U(π/2,0,π) ├┤ U(0,0,2*x[2]) ├┤ U(π/2,0,π) ├
#    └────────────┘└────────────┘└───────────────┘└────────────┘
# Depth: 4
# Gate count: OrderedDict({'u': 12})
# ============================================================
# Y Mapping
#    ┌────────────┐┌─────┐┌───┐┌─────┐┌───────────────┐┌───┐┌───┐┌───┐
# 0: ┤ U(π/2,0,π) ├┤ Sdg ├┤ H ├┤ Sdg ├┤ U(0,0,2*x[0]) ├┤ S ├┤ H ├┤ S ├
#    ├────────────┤├─────┤├───┤├─────┤├───────────────┤├───┤├───┤├───┤
# 1: ┤ U(π/2,0,π) ├┤ Sdg ├┤ H ├┤ Sdg ├┤ U(0,0,2*x[1]) ├┤ S ├┤ H ├┤ S ├
#    ├────────────┤├─────┤├───┤├─────┤├───────────────┤├───┤├───┤├───┤
# 2: ┤ U(π/2,0,π) ├┤ Sdg ├┤ H ├┤ Sdg ├┤ U(0,0,2*x[2]) ├┤ S ├┤ H ├┤ S ├
#    └────────────┘└─────┘└───┘└─────┘└───────────────┘└───┘└───┘└───┘
# Depth: 8
# Gate count: OrderedDict({'u': 6, 'sdg': 6, 'h': 6, 's': 6})
# ============================================================
# Z Mapping
#    ┌────────────┐┌───────────────┐
# 0: ┤ U(π/2,0,π) ├┤ U(0,0,2*x[0]) ├
#    ├────────────┤├───────────────┤
# 1: ┤ U(π/2,0,π) ├┤ U(0,0,2*x[1]) ├
#    ├────────────┤├───────────────┤
# 2: ┤ U(π/2,0,π) ├┤ U(0,0,2*x[2]) ├
#    └────────────┘└───────────────┘
# Depth: 2
# Gate count: OrderedDict({'u': 6})
