# %% [markdown]
# <a href="https://colab.research.google.com/github/umyunsang/edu/blob/main/ComputerScience/03_ai-ml-data/quantum-ml/02.circuits-and-encoding/02.feature-encoding/day16_02_03_combined_pauli_feature_maps_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day16 combined-Pauli feature map 비교 실습
#
# - Source: Google Drive `Day16/2-3.py`
# - Runtime: Google Colab recommended. Do not install or execute dependencies locally for sync validation.

# %%
import warnings

warnings.filterwarnings(
    "ignore",
    category=DeprecationWarning
)

from qiskit.circuit.library import PauliFeatureMap

# =====================================================
# Feature Map 설정
# =====================================================

feature_dim = 3
reps = 1
entanglement = "linear"

# =====================================================
# Pauli 조합 정의
# =====================================================

combined_paulis = {
    "Z + ZZ": ["Z", "ZZ"],
    "X + XX": ["X", "XX"],
    "Y + YY": ["Y", "YY"],
    "X + Y + Z + ZZ": ["X", "Y", "Z", "ZZ"]
}

# =====================================================
# Feature Map 생성
# =====================================================

combined_maps = {}

for name, paulis in combined_paulis.items():

    combined_maps[name] = PauliFeatureMap(
        feature_dimension=feature_dim,
        reps=reps,
        paulis=paulis,
        entanglement=entanglement
    )

# =====================================================
# 결과 출력
# =====================================================

for name, fmap in combined_maps.items():

    circuit = fmap.decompose()

    print("=" * 60)
    print(name)
    print(circuit)
    print(f"Depth      : {circuit.depth()}")
    print(f"Gate Count : {circuit.count_ops()}")
# Out:
# ============================================================
# Z + ZZ
#      ┌───┐┌───────────┐                                             »
# q_0: ┤ H ├┤ P(2*x[0]) ├──■──────────────────────────────────■───────»
#      ├───┤├───────────┤┌─┴─┐┌────────────────────────────┐┌─┴─┐     »
# q_1: ┤ H ├┤ P(2*x[1]) ├┤ X ├┤ P(2*(π - x[0])*(π - x[1])) ├┤ X ├──■──»
#      ├───┤├───────────┤└───┘└────────────────────────────┘└───┘┌─┴─┐»
# q_2: ┤ H ├┤ P(2*x[2]) ├────────────────────────────────────────┤ X ├»
#      └───┘└───────────┘                                        └───┘»
# «
# «q_0: ───────────────────────────────────
# «
# «q_1: ────────────────────────────────■──
# «     ┌────────────────────────────┐┌─┴─┐
# «q_2: ┤ P(2*(π - x[1])*(π - x[2])) ├┤ X ├
# «     └────────────────────────────┘└───┘
# Depth      : 8
# Gate Count : OrderedDict({'p': 5, 'cx': 4, 'h': 3})
# ============================================================
# X + XX
#      ┌───┐┌───┐┌───────────┐┌───┐┌───┐                                        »
# q_0: ┤ H ├┤ H ├┤ P(2*x[0]) ├┤ H ├┤ H ├──■──────────────────────────────────■──»
#      ├───┤├───┤├───────────┤├───┤├───┤┌─┴─┐┌────────────────────────────┐┌─┴─┐»
# q_1: ┤ H ├┤ H ├┤ P(2*x[1]) ├┤ H ├┤ H ├┤ X ├┤ P(2*(π - x[0])*(π - x[1])) ├┤ X ├»
#      ├───┤├───┤├───────────┤├───┤├───┤└───┘└────────────────────────────┘└───┘»
# q_2: ┤ H ├┤ H ├┤ P(2*x[2]) ├┤ H ├┤ H ├────────────────────────────────────────»
#      └───┘└───┘└───────────┘└───┘└───┘                                        »
# «     ┌───┐
# «q_0: ┤ H ├──────────────────────────────────────────────────
# «     ├───┤┌───┐                                        ┌───┐
# «q_1: ┤ H ├┤ H ├──■──────────────────────────────────■──┤ H ├
# «     └───┘└───┘┌─┴─┐┌────────────────────────────┐┌─┴─┐├───┤
# «q_2: ──────────┤ X ├┤ P(2*(π - x[1])*(π - x[2])) ├┤ X ├┤ H ├
# «               └───┘└────────────────────────────┘└───┘└───┘
# Depth      : 14
# Gate Count : OrderedDict({'h': 17, 'p': 5, 'cx': 4})
# ============================================================
# Y + YY
#      ┌───┐┌────┐┌───────────┐┌──────┐┌────┐                                   »
# q_0: ┤ H ├┤ √X ├┤ P(2*x[0]) ├┤ √Xdg ├┤ √X ├──■────────────────────────────────»
#      ├───┤├────┤├───────────┤├──────┤├────┤┌─┴─┐┌────────────────────────────┐»
# q_1: ┤ H ├┤ √X ├┤ P(2*x[1]) ├┤ √Xdg ├┤ √X ├┤ X ├┤ P(2*(π - x[0])*(π - x[1])) ├»
#      ├───┤├────┤├───────────┤├──────┤├────┤└───┘└────────────────────────────┘»
# q_2: ┤ H ├┤ √X ├┤ P(2*x[2]) ├┤ √Xdg ├┤ √X ├───────────────────────────────────»
#      └───┘└────┘└───────────┘└──────┘└────┘                                   »
# «          ┌──────┐
# «q_0: ──■──┤ √Xdg ├──────────────────────────────────────────────────────
# «     ┌─┴─┐├──────┤┌────┐                                        ┌──────┐
# «q_1: ┤ X ├┤ √Xdg ├┤ √X ├──■──────────────────────────────────■──┤ √Xdg ├
# «     └───┘└──────┘└────┘┌─┴─┐┌────────────────────────────┐┌─┴─┐├──────┤
# «q_2: ───────────────────┤ X ├┤ P(2*(π - x[1])*(π - x[2])) ├┤ X ├┤ √Xdg ├
# «                        └───┘└────────────────────────────┘└───┘└──────┘
# Depth      : 14
# Gate Count : OrderedDict({'sx': 7, 'sxdg': 7, 'p': 5, 'cx': 4, 'h': 3})
# ============================================================
# X + Y + Z + ZZ
#      ┌───┐┌───┐┌───────────┐┌───┐┌────┐┌───────────┐┌──────┐┌───────────┐     »
# q_0: ┤ H ├┤ H ├┤ P(2*x[0]) ├┤ H ├┤ √X ├┤ P(2*x[0]) ├┤ √Xdg ├┤ P(2*x[0]) ├──■──»
#      ├───┤├───┤├───────────┤├───┤├────┤├───────────┤├──────┤├───────────┤┌─┴─┐»
# q_1: ┤ H ├┤ H ├┤ P(2*x[1]) ├┤ H ├┤ √X ├┤ P(2*x[1]) ├┤ √Xdg ├┤ P(2*x[1]) ├┤ X ├»
#      ├───┤├───┤├───────────┤├───┤├────┤├───────────┤├──────┤├───────────┤└───┘»
# q_2: ┤ H ├┤ H ├┤ P(2*x[2]) ├┤ H ├┤ √X ├┤ P(2*x[2]) ├┤ √Xdg ├┤ P(2*x[2]) ├─────»
#      └───┘└───┘└───────────┘└───┘└────┘└───────────┘└──────┘└───────────┘     »
# «                                                                           »
# «q_0: ────────────────────────────────■─────────────────────────────────────»
# «     ┌────────────────────────────┐┌─┴─┐                                   »
# «q_1: ┤ P(2*(π - x[0])*(π - x[1])) ├┤ X ├──■────────────────────────────────»
# «     └────────────────────────────┘└───┘┌─┴─┐┌────────────────────────────┐»
# «q_2: ───────────────────────────────────┤ X ├┤ P(2*(π - x[1])*(π - x[2])) ├»
# «                                        └───┘└────────────────────────────┘»
# «
# «q_0: ─────
# «
# «q_1: ──■──
# «     ┌─┴─┐
# «q_2: ┤ X ├
# «     └───┘
# Depth      : 14
# Gate Count : OrderedDict({'p': 11, 'h': 9, 'cx': 4, 'sx': 3, 'sxdg': 3})
