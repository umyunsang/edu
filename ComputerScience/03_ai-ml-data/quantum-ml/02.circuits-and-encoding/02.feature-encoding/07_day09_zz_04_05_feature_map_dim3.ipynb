# %% [markdown]
# # ZZ-4-5.py
#
# Colab-ready practice notebook converted from the shared Google Drive Python source.

# %%
from qiskit.circuit.library import zz_feature_map

feature_map = zz_feature_map(
    feature_dimension=3,
    reps=1
)

print(feature_map)
feature_map.count_ops()

feature_map.draw("mpl")

from matplotlib import pyplot as plt
plt.show()
# Out:
#    ┌───┐┌───────────┐                                               »
# 0: ┤ H ├┤ P(2*x[0]) ├──■────────────────────────────────────■────■──»
#    ├───┤├───────────┤┌─┴─┐┌──────────────────────────────┐┌─┴─┐  │  »
# 1: ┤ H ├┤ P(2*x[1]) ├┤ X ├┤ P((-π + x[0])*(-π + x[1])*2) ├┤ X ├──┼──»
#    ├───┤├───────────┤└───┘└──────────────────────────────┘└───┘┌─┴─┐»
# 2: ┤ H ├┤ P(2*x[2]) ├──────────────────────────────────────────┤ X ├»
#    └───┘└───────────┘                                          └───┘»
# «                                                                             »
# «0: ──────────────────────────────────■───────────────────────────────────────»
# «                                     │                                       »
# «1: ──────────────────────────────────┼────■──────────────────────────────────»
# «   ┌──────────────────────────────┐┌─┴─┐┌─┴─┐┌──────────────────────────────┐»
# «2: ┤ P((-π + x[0])*(-π + x[2])*2) ├┤ X ├┤ X ├┤ P((-π + x[1])*(-π + x[2])*2) ├»
# «   └──────────────────────────────┘└───┘└───┘└──────────────────────────────┘»
# «
# «0: ─────
# «
# «1: ──■──
# «   ┌─┴─┐
# «2: ┤ X ├
# «   └───┘
