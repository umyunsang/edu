# %% [markdown]
# # Day6 two-Hadamard two-qubit practice
#
# Source: Google Drive Day6/3-1-3.py

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram

sim = AerSimulator()

qc = QuantumCircuit(2)
qc.h(0)
qc.h(1)
qc.measure_all()

job = sim.run(qc, shots=1000)
result = job.result()
counts = result.get_counts()

print(counts)
plot_histogram(counts)
# Out:
# {'00': 246, '11': 254, '10': 244, '01': 256}
