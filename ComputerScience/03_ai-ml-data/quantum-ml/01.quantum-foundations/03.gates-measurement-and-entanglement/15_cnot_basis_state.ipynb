# %% [markdown]
# <a href="https://colab.research.google.com/github/umyunsang/edu/blob/main/ComputerScience/03_ai-ml-data/quantum-ml/01.quantum-foundations/03.gates-measurement-and-entanglement/15_cnot_basis_state.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3-1. CNOT Basis-State Practice
#
# Source: Google Drive `Day8/3-1.py`
# Drive file ID: `1C6bKbtut_BsZSmI3vr5Tm-z4nYGlODfj`
# Modified: `2026-06-30T09:28:58.000Z`
#
# CNOT gate alone acts on the initial |00> state, so the expected measurement remains concentrated on 00.

# %% [markdown]
# ## Outline
#
# 1. Review the source circuit.
# 2. Run the original Qiskit practice code in Colab.
# 3. Interpret the measurement counts.
# 4. Try one small variation.

# %% [markdown]
# ## Original Practice Code
#
# This cell preserves the instructor-provided script as a runnable notebook cell. If Colab does not already have Qiskit packages available, install them in the runtime before running this cell.

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram

qc1 = QuantumCircuit(2)

qc1.cx(0, 1)

qc1.measure_all()

qc1.draw("mpl")

sim = AerSimulator()

job = sim.run(qc1, shots=1000)

result = job.result()

counts1 = result.get_counts()

print(counts1)

plot_histogram(counts1)

import matplotlib.pyplot as plt
plt.show()
# Out:
# {'00': 1000}

# %% [markdown]
# ## Checkpoint
#
# CNOT gate alone acts on the initial |00> state, so the expected measurement remains concentrated on 00.

# %% [markdown]
# ## Exercise
#
# Change the initial state with x(0) before cx(0, 1), then predict which bitstring should dominate.
