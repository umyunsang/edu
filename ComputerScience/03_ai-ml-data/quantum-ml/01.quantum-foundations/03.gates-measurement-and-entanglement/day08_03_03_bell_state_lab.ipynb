# %% [markdown]
# <a href="https://colab.research.google.com/github/umyunsang/edu/blob/main/ComputerScience/03_ai-ml-data/quantum-ml/01.quantum-foundations/03.gates-measurement-and-entanglement/day08_03_03_bell_state_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3-3. Bell-State Practice
#
# Source: Google Drive `Day8/3-3.py`
# Drive file ID: `1YVazSFPi6JlSEB7Igjarmr9a6JH9Wb5s`
# Modified: `2026-06-30T09:29:15.000Z`
#
# Hadamard followed by CNOT prepares a Bell-state style entangled circuit with correlated measurement outcomes.

# %% [markdown]
# ## Outline
#
# 1. Review the source circuit.
# 2. Run the original Qiskit practice code in Colab.
# 3. Interpret the measurement counts.
# 4. Try one small variation.

# %% [markdown]
# ## Original Practice Code
#
# This cell preserves the instructor-provided script as a runnable notebook cell. If Colab does not already have Qiskit packages available, install them in the runtime before running this cell.

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram

qc3 = QuantumCircuit(2)

qc3.h(0)

qc3.cx(0, 1)

qc3.measure_all()

qc3.draw("mpl")

sim = AerSimulator()

job = sim.run(qc3, shots=1000)

result = job.result()

counts3 = result.get_counts()

print(counts3)

plot_histogram(counts3)

import matplotlib.pyplot as plt
plt.show()

# %% [markdown]
# ## Checkpoint
#
# Hadamard followed by CNOT prepares a Bell-state style entangled circuit with correlated measurement outcomes.

# %% [markdown]
# ## Exercise
#
# Remove the CNOT gate and compare the histogram against the Bell-state version.
