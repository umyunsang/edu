# %% [markdown]
# # Day6 Hadamard 10-shot practice
#
# Source: Google Drive Day6/2-1.py

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

qc = QuantumCircuit(1)

qc.h(0)

qc.measure_all()

sim = AerSimulator()

job = sim.run(qc, shots=10)

result = job.result()

counts = result.get_counts()

print(counts)
# Out:
# {'1': 4, '0': 6}
