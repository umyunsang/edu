# %% [markdown]
# # Canny Edge Detection (캐니 에지 검출) 실습
#
# 가우시안 블러로 노이즈를 제거한 뒤 `cv2.Canny`로 에지를 검출합니다.

# %%
import cv2
import numpy as np
import urllib.request
from google.colab.patches import cv2_imshow

url = 'https://raw.githubusercontent.com/opencv/opencv/master/samples/data/fruits.jpg'
urllib.request.urlretrieve(url, 'fruits.jpg')

# 이미지 읽기
img = cv2.imread('fruits.jpg')

# 에지 검출 성능을 높이기 위해 흑백(Grayscale) 변환
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# 가우시안 블러로 노이즈 제거
blur = cv2.GaussianBlur(gray, (5, 5), 0)

# 캐니 에지 적용
# cv2.Canny(이미지, 하한 임계값, 상한 임계값)
edges = cv2.Canny(blur, 100, 200)

# 결과 출력 (원본과 에지 영상)
print("--- 원본 이미지 ---")
cv2_imshow(img)

print("\n--- 캐니 에지 결과 ---")
cv2_imshow(edges)
